# %% [markdown]
# # Logistic Regression with a Neural Network mindset
#
# Welcome to your first (required) programming assignment! You will build a logistic regression classifier to recognize  cats. This assignment will step you through how to do this with a Neural Network mindset, and so will also hone your intuitions about deep learning.
#
# **Instructions:**
# - Do not use loops (for/while) in your code, unless the instructions explicitly ask you to do so.
#
# **You will learn to:**
# - Build the general architecture of a learning algorithm, including:
#     - Initializing parameters
#     - Calculating the cost function and its gradient
#     - Using an optimization algorithm (gradient descent)
# - Gather all three functions above into a main model function, in the right order.

# %% [markdown]
# ## <font color='darkblue'>Updates</font>
# This notebook has been updated over the past few months.  The prior version was named "v5", and the current versionis now named '6a'
#
# #### If you were working on a previous version:
# * You can find your prior work by looking in the file directory for the older files (named by version name).
# * To view the file directory, click on the "Coursera" icon in the top left corner of this notebook.
# * Please copy your work from the older versions to the new version, in order to submit your work for grading.
#
# #### List of Updates
# * Forward propagation formula, indexing now starts at 1 instead of 0.
# * Optimization function comment now says "print cost every 100 training iterations" instead of "examples".
# * Fixed grammar in the comments.
# * Y_prediction_test variable name is used consistently.
# * Plot's axis label now says "iterations (hundred)" instead of "iterations".
# * When testing the model, the test image is normalized by dividing by 255.

# %% [markdown]
# ## 1 - Packages ##
#
# First, let's run the cell below to import all the packages that you will need during this assignment.
# - [numpy](www.numpy.org) is the fundamental package for scientific computing with Python.
# - [h5py](http://www.h5py.org) is a common package to interact with a dataset that is stored on an H5 file.
# - [matplotlib](http://matplotlib.org) is a famous library to plot graphs in Python.
# - [PIL](http://www.pythonware.com/products/pil/) and [scipy](https://www.scipy.org/) are used here to test your model with your own picture at the end.

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage
from lr_utils import load_dataset

# %matplotlib inline

# %% [markdown]
# ## 2 - Overview of the Problem set ##
#
# **Problem Statement**: You are given a dataset ("data.h5") containing:
#     - a training set of m_train images labeled as cat (y=1) or non-cat (y=0)
#     - a test set of m_test images labeled as cat or non-cat
#     - each image is of shape (num_px, num_px, 3) where 3 is for the 3 channels (RGB). Thus, each image is square (height = num_px) and (width = num_px).
#
# You will build a simple image-recognition algorithm that can correctly classify pictures as cat or non-cat.
#
# Let's get more familiar with the dataset. Load the data by running the following code.

# %%
# Loading the data (cat/non-cat)
train_set_x_orig, train_set_y, test_set_x_orig, test_set_y, classes = load_dataset()

# %% [markdown]
# We added "_orig" at the end of image datasets (train and test) because we are going to preprocess them. After preprocessing, we will end up with train_set_x and test_set_x (the labels train_set_y and test_set_y don't need any preprocessing).
#
# Each line of your train_set_x_orig and test_set_x_orig is an array representing an image. You can visualize an example by running the following code. Feel free also to change the `index` value and re-run to see other images.

# %%
# Example of a picture
index = 2
plt.imshow(train_set_x_orig[index])
print ("y = " + str(train_set_y[:, index]) + ", it's a '" + classes[np.squeeze(train_set_y[:, index])].decode("utf-8") +  "' picture.")
# Out:
# y = [1], it's a 'cat' picture.

# %% [markdown]
# Many software bugs in deep learning come from having matrix/vector dimensions that don't fit. If you can keep your matrix/vector dimensions straight you will go a long way toward eliminating many bugs.
#
# **Exercise:** Find the values for:
#     - m_train (number of training examples)
#     - m_test (number of test examples)
#     - num_px (= height = width of a training image)
# Remember that `train_set_x_orig` is a numpy-array of shape (m_train, num_px, num_px, 3). For instance, you can access `m_train` by writing `train_set_x_orig.shape[0]`.

# %%
### START CODE HERE ### (≈ 3 lines of code)
m_train = train_set_x_orig.shape[0]
m_test = test_set_x_orig.shape[0]
num_px = train_set_x_orig.shape[2]
### END CODE HERE ###

print ("Number of training examples: m_train = " + str(m_train))
print ("Number of testing examples: m_test = " + str(m_test))
print ("Height/Width of each image: num_px = " + str(num_px))
print ("Each image is of size: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("train_set_x shape: " + str(train_set_x_orig.shape))
print ("train_set_y shape: " + str(train_set_y.shape))
print ("test_set_x shape: " + str(test_set_x_orig.shape))
print ("test_set_y shape: " + str(test_set_y.shape))
# Out:
# Number of training examples: m_train = 209
# Number of testing examples: m_test = 50
# Height/Width of each image: num_px = 64
# Each image is of size: (64, 64, 3)
# train_set_x shape: (209, 64, 64, 3)
# train_set_y shape: (1, 209)
# test_set_x shape: (50, 64, 64, 3)
# test_set_y shape: (1, 50)

# %% [markdown]
# **Expected Output for m_train, m_test and num_px**:
# <table style="width:15%">
#   <tr>
#     <td>**m_train**</td>
#     <td> 209 </td>
#   </tr>
#
#   <tr>
#     <td>**m_test**</td>
#     <td> 50 </td>
#   </tr>
#
#   <tr>
#     <td>**num_px**</td>
#     <td> 64 </td>
#   </tr>
#
# </table>

# %% [markdown]
# For convenience, you should now reshape images of shape (num_px, num_px, 3) in a numpy-array of shape (num_px $*$ num_px $*$ 3, 1). After this, our training (and test) dataset is a numpy-array where each column represents a flattened image. There should be m_train (respectively m_test) columns.
#
# **Exercise:** Reshape the training and test data sets so that images of size (num_px, num_px, 3) are flattened into single vectors of shape (num\_px $*$ num\_px $*$ 3, 1).
#
# A trick when you want to flatten a matrix X of shape (a,b,c,d) to a matrix X_flatten of shape (b$*$c$*$d, a) is to use:
# ```python
# X_flatten = X.reshape(X.shape[0], -1).T      # X.T is the transpose of X
# ```

# %%
# Reshape the training and test examples

### START CODE HERE ### (≈ 2 lines of code)
train_set_x_flatten = train_set_x_orig.reshape(train_set_x_orig.shape[0],-1).T
test_set_x_flatten = test_set_x_orig.reshape(test_set_x_orig.shape[0],-1).T
### END CODE HERE ###

print ("train_set_x_flatten shape: " + str(train_set_x_flatten.shape))
print ("train_set_y shape: " + str(train_set_y.shape))
print ("test_set_x_flatten shape: " + str(test_set_x_flatten.shape))
print ("test_set_y shape: " + str(test_set_y.shape))
print ("sanity check after reshaping: " + str(train_set_x_flatten[0:5,0]))
# Out:
# train_set_x_flatten shape: (12288, 209)
# train_set_y shape: (1, 209)
# test_set_x_flatten shape: (12288, 50)
# test_set_y shape: (1, 50)
# sanity check after reshaping: [17 31 56 22 33]

# %%
train_set_x_orig.reshape(train_set_x_orig.shape[1]*train_set_x_orig.shape[2]*train_set_x_orig.shape[3],train_set_x_orig.shape[0]).shape
# Out:
# (12288, 209)

# %% [markdown]
# **Expected Output**:
#
# <table style="width:35%">
#   <tr>
#     <td>**train_set_x_flatten shape**</td>
#     <td> (12288, 209)</td>
#   </tr>
#   <tr>
#     <td>**train_set_y shape**</td>
#     <td>(1, 209)</td>
#   </tr>
#   <tr>
#     <td>**test_set_x_flatten shape**</td>
#     <td>(12288, 50)</td>
#   </tr>
#   <tr>
#     <td>**test_set_y shape**</td>
#     <td>(1, 50)</td>
#   </tr>
#   <tr>
#   <td>**sanity check after reshaping**</td>
#   <td>[17 31 56 22 33]</td>
#   </tr>
# </table>

# %% [markdown]
# To represent color images, the red, green and blue channels (RGB) must be specified for each pixel, and so the pixel value is actually a vector of three numbers ranging from 0 to 255.
#
# One common preprocessing step in machine learning is to center and standardize your dataset, meaning that you substract the mean of the whole numpy array from each example, and then divide each example by the standard deviation of the whole numpy array. But for picture datasets, it is simpler and more convenient and works almost as well to just divide every row of the dataset by 255 (the maximum value of a pixel channel).
#
# <!-- During the training of your model, you're going to multiply weights and add biases to some initial inputs in order to observe neuron activations. Then you backpropogate with the gradients to train the model. But, it is extremely important for each feature to have a similar range such that our gradients don't explode. You will see that more in detail later in the lectures. !-->
#
# Let's standardize our dataset.

# %%
train_set_x = train_set_x_flatten/255.
test_set_x = test_set_x_flatten/255.

# %% [markdown]
# <font color='blue'>
# **What you need to remember:**
#
# Common steps for pre-processing a new dataset are:
# - Figure out the dimensions and shapes of the problem (m_train, m_test, num_px, ...)
# - Reshape the datasets such that each example is now a vector of size (num_px \* num_px \* 3, 1)
# - "Standardize" the data

# %% [markdown]
# ## 3 - General Architecture of the learning algorithm ##
#
# It's time to design a simple algorithm to distinguish cat images from non-cat images.
#
# You will build a Logistic Regression, using a Neural Network mindset. The following Figure explains why **Logistic Regression is actually a very simple Neural Network!**
#
# <img src="images/LogReg_kiank.png" style="width:650px;height:400px;">
#
# **Mathematical expression of the algorithm**:
#
# For one example $x^{(i)}$:
# $$z^{(i)} = w^T x^{(i)} + b \tag{1}$$
# $$\hat{y}^{(i)} = a^{(i)} = sigmoid(z^{(i)})\tag{2}$$
# $$ \mathcal{L}(a^{(i)}, y^{(i)}) =  - y^{(i)}  \log(a^{(i)}) - (1-y^{(i)} )  \log(1-a^{(i)})\tag{3}$$
#
# The cost is then computed by summing over all training examples:
# $$ J = \frac{1}{m} \sum_{i=1}^m \mathcal{L}(a^{(i)}, y^{(i)})\tag{6}$$
#
# **Key steps**:
# In this exercise, you will carry out the following steps:
#     - Initialize the parameters of the model
#     - Learn the parameters for the model by minimizing the cost
#     - Use the learned parameters to make predictions (on the test set)
#     - Analyse the results and conclude

# %% [markdown]
# ## 4 - Building the parts of our algorithm ##
#
# The main steps for building a Neural Network are:
# 1. Define the model structure (such as number of input features)
# 2. Initialize the model's parameters
# 3. Loop:
#     - Calculate current loss (forward propagation)
#     - Calculate current gradient (backward propagation)
#     - Update parameters (gradient descent)
#
# You often build 1-3 separately and integrate them into one function we call `model()`.
#
# ### 4.1 - Helper functions
#
# **Exercise**: Using your code from "Python Basics", implement `sigmoid()`. As you've seen in the figure above, you need to compute $sigmoid( w^T x + b) = \frac{1}{1 + e^{-(w^T x + b)}}$ to make predictions. Use np.exp().

# %%
# GRADED FUNCTION: sigmoid

def sigmoid(z):
    """
    Compute the sigmoid of z

    Arguments:
    z -- A scalar or numpy array of any size.

    Return:
    s -- sigmoid(z)
    """

    ### START CODE HERE ### (≈ 1 line of code)
    s = 1/(1+np.exp(-z))
    ### END CODE HERE ###
    
    return s

# %%
print ("sigmoid([0, 2]) = " + str(sigmoid(np.array([0,2]))))
# Out:
# sigmoid([0, 2]) = [ 0.5         0.88079708]

# %% [markdown]
# **Expected Output**:
#
# <table>
#   <tr>
#     <td>**sigmoid([0, 2])**</td>
#     <td> [ 0.5         0.88079708]</td>
#   </tr>
# </table>

# %% [markdown]
# ### 4.2 - Initializing parameters
#
# **Exercise:** Implement parameter initialization in the cell below. You have to initialize w as a vector of zeros. If you don't know what numpy function to use, look up np.zeros() in the Numpy library's documentation.

# %%
# GRADED FUNCTION: initialize_with_zeros

def initialize_with_zeros(dim):
    """
    This function creates a vector of zeros of shape (dim, 1) for w and initializes b to 0.
    
    Argument:
    dim -- size of the w vector we want (or number of parameters in this case)
    
    Returns:
    w -- initialized vector of shape (dim, 1)
    b -- initialized scalar (corresponds to the bias)
    """
  
    
    ### START CODE HERE ### (≈ 1 line of code)
    w = np.zeros((dim,1))
    b = 0
    ### END CODE HERE ###

    assert(w.shape == (dim, 1))
    assert(isinstance(b, float) or isinstance(b, int))
    
    return w, b

# %%
dim = 2
w, b = initialize_with_zeros(dim)
print ("w = " + str(w))
print ("b = " + str(b))
# Out:
# w = [[ 0.]
#  [ 0.]]
# b = 0

# %%
w.shape
# Out:
# (2, 1)

# %% [markdown]
# **Expected Output**:
#
#
# <table style="width:15%">
#     <tr>
#         <td>  ** w **  </td>
#         <td> [[ 0.]
#  [ 0.]] </td>
#     </tr>
#     <tr>
#         <td>  ** b **  </td>
#         <td> 0 </td>
#     </tr>
# </table>
#
# For image inputs, w will be of shape (num_px $\times$ num_px $\times$ 3, 1).

# %% [markdown]
# ### 4.3 - Forward and Backward propagation
#
# Now that your parameters are initialized, you can do the "forward" and "backward" propagation steps for learning the parameters.
#
# **Exercise:** Implement a function `propagate()` that computes the cost function and its gradient.
#
# **Hints**:
#
# Forward Propagation:
# - You get X
# - You compute $A = \sigma(w^T X + b) = (a^{(1)}, a^{(2)}, ..., a^{(m-1)}, a^{(m)})$
# - You calculate the cost function: $J = -\frac{1}{m}\sum_{i=1}^{m}y^{(i)}\log(a^{(i)})+(1-y^{(i)})\log(1-a^{(i)})$
#
# Here are the two formulas you will be using:
#
# $$ \frac{\partial J}{\partial w} = \frac{1}{m}X(A-Y)^T\tag{7}$$
# $$ \frac{\partial J}{\partial b} = \frac{1}{m} \sum_{i=1}^m (a^{(i)}-y^{(i)})\tag{8}$$

# %%
# GRADED FUNCTION: propagate

def propagate(w, b, X, Y):
    """
    Implement the cost function and its gradient for the propagation explained above

    Arguments:
    w -- weights, a numpy array of size (num_px * num_px * 3, 1)
    b -- bias, a scalar
    X -- data of size (num_px * num_px * 3, number of examples)
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat) of size (1, number of examples)

    Return:
    cost -- negative log-likelihood cost for logistic regression
    dw -- gradient of the loss with respect to w, thus same shape as w
    db -- gradient of the loss with respect to b, thus same shape as b
    
    Tips:
    - Write your code step by step for the propagation. np.log(), np.dot()
    """
    
    m = X.shape[1]
    
    # FORWARD PROPAGATION (FROM X TO COST)
    ### START CODE HERE ### (≈ 2 lines of code)
    A = sigmoid(np.dot(w.T,X)+b)  # compute activation
    cost =(-1/m)*np.sum((np.dot(Y,np.log(A).T)+np.dot((1-Y),np.log(1-A).T)))                                # compute cost
    ### END CODE HERE ###
    
    # BACKWARD PROPAGATION (TO FIND GRAD)
    ### START CODE HERE ### (≈ 2 lines of code)
    dw = 1/m*np.dot(X,(A-Y).T)
    db = 1/m*np.sum(A-Y)
    ### END CODE HERE ###

    assert(dw.shape == w.shape)
    assert(db.dtype == float)
    cost = np.squeeze(cost)
    assert(cost.shape == ())
    
    grads = {"dw": dw,
             "db": db}
    
    return grads, cost

# %%
w, b, X, Y = np.array([[1.],[2.]]), 2., np.array([[1.,2.,-1.],[3.,4.,-3.2]]), np.array([[1,0,1]])
grads, cost = propagate(w, b, X, Y)
print ("dw = " + str(grads["dw"]))
print ("db = " + str(grads["db"]))
print ("cost = " + str(cost))
# Out:
# dw = [[ 0.99845601]
#  [ 2.39507239]]
# db = 0.00145557813678
# cost = 5.80154531939

# %%
grads
# Out:
# {'db': 0.001455578136784208, 'dw': array([[ 0.99845601],
#         [ 2.39507239]])}

# %% [markdown]
# **Expected Output**:
#
# <table style="width:50%">
#     <tr>
#         <td>  ** dw **  </td>
#       <td> [[ 0.99845601]
#      [ 2.39507239]]</td>
#     </tr>
#     <tr>
#         <td>  ** db **  </td>
#         <td> 0.00145557813678 </td>
#     </tr>
#     <tr>
#         <td>  ** cost **  </td>
#         <td> 5.801545319394553 </td>
#     </tr>
#
# </table>

# %% [markdown]
# ### 4.4 - Optimization
# - You have initialized your parameters.
# - You are also able to compute a cost function and its gradient.
# - Now, you want to update the parameters using gradient descent.
#
# **Exercise:** Write down the optimization function. The goal is to learn $w$ and $b$ by minimizing the cost function $J$. For a parameter $\theta$, the update rule is $ \theta = \theta - \alpha \text{ } d\theta$, where $\alpha$ is the learning rate.

# %%
# GRADED FUNCTION: optimize

def optimize(w, b, X, Y, num_iterations, learning_rate, print_cost = True):
    """
    This function optimizes w and b by running a gradient descent algorithm
    
    Arguments:
    w -- weights, a numpy array of size (num_px * num_px * 3, 1)
    b -- bias, a scalar
    X -- data of shape (num_px * num_px * 3, number of examples)
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat), of shape (1, number of examples)
    num_iterations -- number of iterations of the optimization loop
    learning_rate -- learning rate of the gradient descent update rule
    print_cost -- True to print the loss every 100 steps
    
    Returns:
    params -- dictionary containing the weights w and bias b
    grads -- dictionary containing the gradients of the weights and bias with respect to the cost function
    costs -- list of all the costs computed during the optimization, this will be used to plot the learning curve.
    
    Tips:
    You basically need to write down two steps and iterate through them:
        1) Calculate the cost and the gradient for the current parameters. Use propagate().
        2) Update the parameters using gradient descent rule for w and b.
    """
    
    costs = []
    
    for i in range(num_iterations):
        
        
        # Cost and gradient calculation (≈ 1-4 lines of code)
        ### START CODE HERE ### 
        grads, cost  = propagate(w, b, X, Y)
        ### END CODE HERE ###
        
        # Retrieve derivatives from grads
        dw = grads["dw"]
        db = grads["db"]
        
        # update rule (≈ 2 lines of code)
        ### START CODE HERE ###
        w = w-learning_rate*dw
        b = b-learning_rate*db
        ### END CODE HERE ###
        
        # Record the costs
        if i % 10 == 0:
            costs.append(cost)
        
        # Print the cost every 100 training iterations
        if print_cost and i % 10 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
    
    params = {"w": w,
              "b": b}
    
    grads = {"dw": dw,
             "db": db}
    
    return params, grads, costs

# %%
optimize(w, b, X, Y, num_iterations= 10000, learning_rate = 0.09, print_cost = True)
# Out:
# Cost after iteration 0: 0.807736
# Cost after iteration 10: 0.715761
# Cost after iteration 20: 0.678255
# Cost after iteration 30: 0.650369
# Cost after iteration 40: 0.625646
# Cost after iteration 50: 0.602708
# Cost after iteration 60: 0.581114
# Cost after iteration 70: 0.560672
# Cost after iteration 80: 0.541278
# Cost after iteration 90: 0.522859
# Cost after iteration 100: 0.505357
# Cost after iteration 110: 0.488720
# Cost after iteration 120: 0.472898
# Cost after iteration 130: 0.457847
# Cost after iteration 140: 0.443522
# Cost after iteration 150: 0.429884
# Cost after iteration 160: 0.416892
# Cost after iteration 170: 0.404512
# Cost after iteration 180: 0.392707
# Cost after iteration 190: 0.381446
# Cost after iteration 200: 0.370698
# Cost after iteration 210: 0.360434
# Cost after iteration 220: 0.350627
# Cost after iteration 230: 0.341253
# Cost after iteration 240: 0.332286
# Cost after iteration 250: 0.323704
# Cost after iteration 260: 0.315487
# Cost after iteration 270: 0.307615
# Cost after iteration 280: 0.300069
# Cost after iteration 290: 0.292831
# Cost after iteration 300: 0.285886
# Cost after iteration 310: 0.279218
# Cost after iteration 320: 0.272813
# Cost after iteration 330: 0.266656
# Cost after iteration 340: 0.260736
# Cost after iteration 350: 0.255040
# Cost after iteration 360: 0.249558
# Cost after iteration 370: 0.244278
# Cost after iteration 380: 0.239190
# Cost after iteration 390: 0.234286
# Cost after iteration 400: 0.229556
# Cost after iteration 410: 0.224992
# Cost after iteration 420: 0.220586
# Cost after iteration 430: 0.216332
# Cost after iteration 440: 0.212221
# Cost after iteration 450: 0.208247
# Cost after iteration 460: 0.204404
# Cost after iteration 470: 0.200687
# Cost after iteration 480: 0.197089
# Cost after iteration 490: 0.193605
# Cost after iteration 500: 0.190231
# Cost after iteration 510: 0.186962
# Cost after iteration 520: 0.183793
# Cost after iteration 530: 0.180719
# Cost after iteration 540: 0.177738
# Cost after iteration 550: 0.174845
# Cost after iteration 560: 0.172037
# Cost after iteration 570: 0.169310
# Cost after iteration 580: 0.166660
# Cost after iteration 590: 0.164086
# Cost after iteration 600: 0.161583
# Cost after iteration 610: 0.159150
# Cost after iteration 620: 0.156783
# Cost after iteration 630: 0.154480
# Cost after iteration 640: 0.152239
# Cost after iteration 650: 0.150056
# Cost after iteration 660: 0.147931
# Cost after iteration 670: 0.145861
# Cost after iteration 680: 0.143844
# Cost after iteration 690: 0.141877
# Cost after iteration 700: 0.139961
# Cost after iteration 710: 0.138091
# Cost after iteration 720: 0.136268
# Cost after iteration 730: 0.134488
# Cost after iteration 740: 0.132752
# Cost after iteration 750: 0.131057
# Cost after iteration 760: 0.129401
# Cost after iteration 770: 0.127785
# Cost after iteration 780: 0.126205
# Cost after iteration 790: 0.124662
# Cost after iteration 800: 0.123154
# Cost after iteration 810: 0.121679
# Cost after iteration 820: 0.120238
# Cost after iteration 830: 0.118828
# Cost after iteration 840: 0.117449
# Cost after iteration 850: 0.116099
# Cost after iteration 860: 0.114778
# Cost after iteration 870: 0.113486
# Cost after iteration 880: 0.112220
# Cost after iteration 890: 0.110981
# Cost after iteration 900: 0.109768
# Cost after iteration 910: 0.108579
# Cost after iteration 920: 0.107414
# Cost after iteration 930: 0.106273
# Cost after iteration 940: 0.105154
# Cost after iteration 950: 0.104057
# Cost after iteration 960: 0.102982
# Cost after iteration 970: 0.101928
# Cost after iteration 980: 0.100894
# Cost after iteration 990: 0.099880
# Cost after iteration 1000: 0.098884
# Cost after iteration 1010: 0.097908
# Cost after iteration 1020: 0.096950
# Cost after iteration 1030: 0.096009
# Cost after iteration 1040: 0.095085
# Cost after iteration 1050: 0.094179
# Cost after iteration 1060: 0.093288
# Cost after iteration 1070: 0.092414
# Cost after iteration 1080: 0.091555
# Cost after iteration 1090: 0.090711
# Cost after iteration 1100: 0.089881
# Cost after iteration 1110: 0.089066
# Cost after iteration 1120: 0.088265
# Cost after iteration 1130: 0.087478
# Cost after iteration 1140: 0.086704
# Cost after iteration 1150: 0.085943
# Cost after iteration 1160: 0.085195
# Cost after iteration 1170: 0.084459
# Cost after iteration 1180: 0.083735
# Cost after iteration 1190: 0.083023
# Cost after iteration 1200: 0.082322
# Cost after iteration 1210: 0.081633
# Cost after iteration 1220: 0.080954
# Cost after iteration 1230: 0.080286
# Cost after iteration 1240: 0.079629
# Cost after iteration 1250: 0.078982
# Cost after iteration 1260: 0.078345
# Cost after iteration 1270: 0.077718
# Cost after iteration 1280: 0.077100
# Cost after iteration 1290: 0.076492
# Cost after iteration 1300: 0.075893
# Cost after iteration 1310: 0.075303
# Cost after iteration 1320: 0.074721
# Cost after iteration 1330: 0.074149
# Cost after iteration 1340: 0.073584
# Cost after iteration 1350: 0.073028
# Cost after iteration 1360: 0.072480
# Cost after iteration 1370: 0.071939
# Cost after iteration 1380: 0.071407
# Cost after iteration 1390: 0.070881
# Cost after iteration 1400: 0.070364
# Cost after iteration 1410: 0.069853
# Cost after iteration 1420: 0.069350
# Cost after iteration 1430: 0.068853
# Cost after iteration 1440: 0.068364
# Cost after iteration 1450: 0.067881
# Cost after iteration 1460: 0.067404
# Cost after iteration 1470: 0.066934
# Cost after iteration 1480: 0.066471
# Cost after iteration 1490: 0.066013
# Cost after iteration 1500: 0.065562
# Cost after iteration 1510: 0.065116
# Cost after iteration 1520: 0.064676
# Cost after iteration 1530: 0.064242
# Cost after iteration 1540: 0.063814
# Cost after iteration 1550: 0.063391
# Cost after iteration 1560: 0.062973
# Cost after iteration 1570: 0.062561
# Cost after iteration 1580: 0.062154
# Cost after iteration 1590: 0.061752
# Cost after iteration 1600: 0.061355
# Cost after iteration 1610: 0.060963
# Cost after iteration 1620: 0.060575
# Cost after iteration 1630: 0.060193
# Cost after iteration 1640: 0.059815
# Cost after iteration 1650: 0.059442
# Cost after iteration 1660: 0.059073
# Cost after iteration 1670: 0.058709
# Cost after iteration 1680: 0.058348
# Cost after iteration 1690: 0.057993
# Cost after iteration 1700: 0.057641
# Cost after iteration 1710: 0.057294
# Cost after iteration 1720: 0.056950
# Cost after iteration 1730: 0.056611
# Cost after iteration 1740: 0.056275
# Cost after iteration 1750: 0.055943
# Cost after iteration 1760: 0.055615
# Cost after iteration 1770: 0.055291
# Cost after iteration 1780: 0.054970
# Cost after iteration 1790: 0.054653
# Cost after iteration 1800: 0.054340
# Cost after iteration 1810: 0.054030
# Cost after iteration 1820: 0.053723
# Cost after iteration 1830: 0.053420
# Cost after iteration 1840: 0.053120
# Cost after iteration 1850: 0.052824
# Cost after iteration 1860: 0.052530
# Cost after iteration 1870: 0.052240
# Cost after iteration 1880: 0.051953
# Cost after iteration 1890: 0.051668
# Cost after iteration 1900: 0.051387
# Cost after iteration 1910: 0.051109
# Cost after iteration 1920: 0.050834
# Cost after iteration 1930: 0.050562
# Cost after iteration 1940: 0.050292
# Cost after iteration 1950: 0.050025
# Cost after iteration 1960: 0.049761
# Cost after iteration 1970: 0.049500
# Cost after iteration 1980: 0.049241
# Cost after iteration 1990: 0.048985
# Cost after iteration 2000: 0.048732
# Cost after iteration 2010: 0.048481
# Cost after iteration 2020: 0.048233
# Cost after iteration 2030: 0.047987
# Cost after iteration 2040: 0.047743
# Cost after iteration 2050: 0.047502
# Cost after iteration 2060: 0.047263
# Cost after iteration 2070: 0.047027
# Cost after iteration 2080: 0.046793
# Cost after iteration 2090: 0.046561
# Cost after iteration 2100: 0.046331
# Cost after iteration 2110: 0.046104
# Cost after iteration 2120: 0.045879
# Cost after iteration 2130: 0.045656
# Cost after iteration 2140: 0.045435
# Cost after iteration 2150: 0.045216
# Cost after iteration 2160: 0.044999
# Cost after iteration 2170: 0.044784
# Cost after iteration 2180: 0.044571
# Cost after iteration 2190: 0.044360
# Cost after iteration 2200: 0.044151
# Cost after iteration 2210: 0.043944
# Cost after iteration 2220: 0.043739
# Cost after iteration 2230: 0.043536
# Cost after iteration 2240: 0.043334
# Cost after iteration 2250: 0.043135
# Cost after iteration 2260: 0.042937
# Cost after iteration 2270: 0.042741
# Cost after iteration 2280: 0.042546
# Cost after iteration 2290: 0.042354
# Cost after iteration 2300: 0.042163
# Cost after iteration 2310: 0.041974
# Cost after iteration 2320: 0.041786
# Cost after iteration 2330: 0.041600
# Cost after iteration 2340: 0.041416
# Cost after iteration 2350: 0.041233
# Cost after iteration 2360: 0.041052
# Cost after iteration 2370: 0.040872
# Cost after iteration 2380: 0.040694
# Cost after iteration 2390: 0.040518
# Cost after iteration 2400: 0.040343
# Cost after iteration 2410: 0.040169
# Cost after iteration 2420: 0.039997
# Cost after iteration 2430: 0.039826
# Cost after iteration 2440: 0.039657
# Cost after iteration 2450: 0.039489
# Cost after iteration 2460: 0.039323
# Cost after iteration 2470: 0.039157
# Cost after iteration 2480: 0.038994
# Cost after iteration 2490: 0.038831
# Cost after iteration 2500: 0.038670
# Cost after iteration 2510: 0.038510
# Cost after iteration 2520: 0.038352
# Cost after iteration 2530: 0.038195
# Cost after iteration 2540: 0.038039
# Cost after iteration 2550: 0.037884
# Cost after iteration 2560: 0.037730
# Cost after iteration 2570: 0.037578
# Cost after iteration 2580: 0.037427
# Cost after iteration 2590: 0.037277
# Cost after iteration 2600: 0.037128
# Cost after iteration 2610: 0.036981
# Cost after iteration 2620: 0.036834
# Cost after iteration 2630: 0.036689
# Cost after iteration 2640: 0.036545
# Cost after iteration 2650: 0.036402
# Cost after iteration 2660: 0.036260
# Cost after iteration 2670: 0.036119
# Cost after iteration 2680: 0.035979
# Cost after iteration 2690: 0.035840
# Cost after iteration 2700: 0.035703
# Cost after iteration 2710: 0.035566
# Cost after iteration 2720: 0.035430
# Cost after iteration 2730: 0.035296
# Cost after iteration 2740: 0.035162
# Cost after iteration 2750: 0.035029
# Cost after iteration 2760: 0.034898
# Cost after iteration 2770: 0.034767
# Cost after iteration 2780: 0.034637
# Cost after iteration 2790: 0.034508
# Cost after iteration 2800: 0.034380
# Cost after iteration 2810: 0.034253
# Cost after iteration 2820: 0.034127
# Cost after iteration 2830: 0.034002
# Cost after iteration 2840: 0.033878
# Cost after iteration 2850: 0.033755
# Cost after iteration 2860: 0.033632
# Cost after iteration 2870: 0.033511
# Cost after iteration 2880: 0.033390
# Cost after iteration 2890: 0.033270
# Cost after iteration 2900: 0.033151
# Cost after iteration 2910: 0.033033
# Cost after iteration 2920: 0.032916
# Cost after iteration 2930: 0.032799
# Cost after iteration 2940: 0.032683
# Cost after iteration 2950: 0.032568
# Cost after iteration 2960: 0.032454
# Cost after iteration 2970: 0.032341
# Cost after iteration 2980: 0.032228
# Cost after iteration 2990: 0.032116
# Cost after iteration 3000: 0.032005
# Cost after iteration 3010: 0.031895
# Cost after iteration 3020: 0.031786
# Cost after iteration 3030: 0.031677
# Cost after iteration 3040: 0.031569
# Cost after iteration 3050: 0.031461
# Cost after iteration 3060: 0.031355
# Cost after iteration 3070: 0.031249
# Cost after iteration 3080: 0.031143
# Cost after iteration 3090: 0.031039
# Cost after iteration 3100: 0.030935
# Cost after iteration 3110: 0.030832
# Cost after iteration 3120: 0.030729
# Cost after iteration 3130: 0.030628
# Cost after iteration 3140: 0.030526
# Cost after iteration 3150: 0.030426
# Cost after iteration 3160: 0.030326
# Cost after iteration 3170: 0.030227
# Cost after iteration 3180: 0.030128
# Cost after iteration 3190: 0.030030
# Cost after iteration 3200: 0.029933
# Cost after iteration 3210: 0.029836
# Cost after iteration 3220: 0.029740
# Cost after iteration 3230: 0.029645
# Cost after iteration 3240: 0.029550
# Cost after iteration 3250: 0.029455
# Cost after iteration 3260: 0.029362
# Cost after iteration 3270: 0.029269
# Cost after iteration 3280: 0.029176
# Cost after iteration 3290: 0.029084
# Cost after iteration 3300: 0.028993
# Cost after iteration 3310: 0.028902
# Cost after iteration 3320: 0.028812
# Cost after iteration 3330: 0.028722
# Cost after iteration 3340: 0.028633
# Cost after iteration 3350: 0.028544
# Cost after iteration 3360: 0.028456
# Cost after iteration 3370: 0.028368
# Cost after iteration 3380: 0.028281
# Cost after iteration 3390: 0.028195
# Cost after iteration 3400: 0.028109
# Cost after iteration 3410: 0.028024
# Cost after iteration 3420: 0.027939
# Cost after iteration 3430: 0.027854
# Cost after iteration 3440: 0.027770
# Cost after iteration 3450: 0.027687
# Cost after iteration 3460: 0.027604
# Cost after iteration 3470: 0.027521
# Cost after iteration 3480: 0.027439
# Cost after iteration 3490: 0.027358
# Cost after iteration 3500: 0.027277
# Cost after iteration 3510: 0.027196
# Cost after iteration 3520: 0.027116
# Cost after iteration 3530: 0.027037
# Cost after iteration 3540: 0.026957
# Cost after iteration 3550: 0.026879
# Cost after iteration 3560: 0.026800
# Cost after iteration 3570: 0.026723
# Cost after iteration 3580: 0.026645
# Cost after iteration 3590: 0.026568
# Cost after iteration 3600: 0.026492
# Cost after iteration 3610: 0.026416
# Cost after iteration 3620: 0.026340
# Cost after iteration 3630: 0.026265
# Cost after iteration 3640: 0.026190
# Cost after iteration 3650: 0.026116
# Cost after iteration 3660: 0.026042
# Cost after iteration 3670: 0.025968
# Cost after iteration 3680: 0.025895
# Cost after iteration 3690: 0.025823
# Cost after iteration 3700: 0.025750
# Cost after iteration 3710: 0.025678
# Cost after iteration 3720: 0.025607
# Cost after iteration 3730: 0.025536
# Cost after iteration 3740: 0.025465
# Cost after iteration 3750: 0.025395
# Cost after iteration 3760: 0.025325
# Cost after iteration 3770: 0.025255
# Cost after iteration 3780: 0.025186
# Cost after iteration 3790: 0.025117
# Cost after iteration 3800: 0.025049
# Cost after iteration 3810: 0.024980
# Cost after iteration 3820: 0.024913
# Cost after iteration 3830: 0.024845
# Cost after iteration 3840: 0.024778
# Cost after iteration 3850: 0.024712
# Cost after iteration 3860: 0.024645
# Cost after iteration 3870: 0.024579
# Cost after iteration 3880: 0.024514
# Cost after iteration 3890: 0.024448
# Cost after iteration 3900: 0.024384
# Cost after iteration 3910: 0.024319
# Cost after iteration 3920: 0.024255
# Cost after iteration 3930: 0.024191
# Cost after iteration 3940: 0.024127
# Cost after iteration 3950: 0.024064
# Cost after iteration 3960: 0.024001
# Cost after iteration 3970: 0.023938
# Cost after iteration 3980: 0.023876
# Cost after iteration 3990: 0.023814
# Cost after iteration 4000: 0.023753
# Cost after iteration 4010: 0.023691
# Cost after iteration 4020: 0.023630
# Cost after iteration 4030: 0.023570
# Cost after iteration 4040: 0.023509
# Cost after iteration 4050: 0.023449
# Cost after iteration 4060: 0.023389
# Cost after iteration 4070: 0.023330
# Cost after iteration 4080: 0.023271
# Cost after iteration 4090: 0.023212
# Cost after iteration 4100: 0.023153
# Cost after iteration 4110: 0.023095
# Cost after iteration 4120: 0.023037
# Cost after iteration 4130: 0.022979
# Cost after iteration 4140: 0.022922
# Cost after iteration 4150: 0.022864
# Cost after iteration 4160: 0.022807
# Cost after iteration 4170: 0.022751
# Cost after iteration 4180: 0.022695
# Cost after iteration 4190: 0.022638
# Cost after iteration 4200: 0.022583
# Cost after iteration 4210: 0.022527
# Cost after iteration 4220: 0.022472
# Cost after iteration 4230: 0.022417
# Cost after iteration 4240: 0.022362
# Cost after iteration 4250: 0.022308
# Cost after iteration 4260: 0.022254
# Cost after iteration 4270: 0.022200
# Cost after iteration 4280: 0.022146
# Cost after iteration 4290: 0.022093
# Cost after iteration 4300: 0.022039
# Cost after iteration 4310: 0.021987
# Cost after iteration 4320: 0.021934
# Cost after iteration 4330: 0.021882
# Cost after iteration 4340: 0.021829
# Cost after iteration 4350: 0.021777
# Cost after iteration 4360: 0.021726
# Cost after iteration 4370: 0.021674
# Cost after iteration 4380: 0.021623
# Cost after iteration 4390: 0.021572
# Cost after iteration 4400: 0.021521
# Cost after iteration 4410: 0.021471
# Cost after iteration 4420: 0.021421
# Cost after iteration 4430: 0.021371
# Cost after iteration 4440: 0.021321
# Cost after iteration 4450: 0.021271
# Cost after iteration 4460: 0.021222
# Cost after iteration 4470: 0.021173
# Cost after iteration 4480: 0.021124
# Cost after iteration 4490: 0.021075
# Cost after iteration 4500: 0.021027
# Cost after iteration 4510: 0.020979
# Cost after iteration 4520: 0.020931
# Cost after iteration 4530: 0.020883
# Cost after iteration 4540: 0.020835
# Cost after iteration 4550: 0.020788
# Cost after iteration 4560: 0.020741
# Cost after iteration 4570: 0.020694
# Cost after iteration 4580: 0.020647
# Cost after iteration 4590: 0.020601
# Cost after iteration 4600: 0.020555
# Cost after iteration 4610: 0.020508
# Cost after iteration 4620: 0.020463
# Cost after iteration 4630: 0.020417
# Cost after iteration 4640: 0.020371
# Cost after iteration 4650: 0.020326
# Cost after iteration 4660: 0.020281
# Cost after iteration 4670: 0.020236
# Cost after iteration 4680: 0.020191
# Cost after iteration 4690: 0.020147
# Cost after iteration 4700: 0.020103
# Cost after iteration 4710: 0.020059
# Cost after iteration 4720: 0.020015
# Cost after iteration 4730: 0.019971
# Cost after iteration 4740: 0.019927
# Cost after iteration 4750: 0.019884
# Cost after iteration 4760: 0.019841
# Cost after iteration 4770: 0.019798
# Cost after iteration 4780: 0.019755
# Cost after iteration 4790: 0.019712
# Cost after iteration 4800: 0.019670
# Cost after iteration 4810: 0.019628
# Cost after iteration 4820: 0.019586
# Cost after iteration 4830: 0.019544
# Cost after iteration 4840: 0.019502
# Cost after iteration 4850: 0.019460
# Cost after iteration 4860: 0.019419
# Cost after iteration 4870: 0.019378
# Cost after iteration 4880: 0.019337
# Cost after iteration 4890: 0.019296
# Cost after iteration 4900: 0.019255
# Cost after iteration 4910: 0.019215
# Cost after iteration 4920: 0.019174
# Cost after iteration 4930: 0.019134
# Cost after iteration 4940: 0.019094
# Cost after iteration 4950: 0.019054
# Cost after iteration 4960: 0.019015
# Cost after iteration 4970: 0.018975
# Cost after iteration 4980: 0.018936
# Cost after iteration 4990: 0.018897
# Cost after iteration 5000: 0.018858
# Cost after iteration 5010: 0.018819
# Cost after iteration 5020: 0.018780
# Cost after iteration 5030: 0.018742
# Cost after iteration 5040: 0.018703
# Cost after iteration 5050: 0.018665
# Cost after iteration 5060: 0.018627
# Cost after iteration 5070: 0.018589
# Cost after iteration 5080: 0.018551
# Cost after iteration 5090: 0.018513
# Cost after iteration 5100: 0.018476
# Cost after iteration 5110: 0.018439
# Cost after iteration 5120: 0.018401
# Cost after iteration 5130: 0.018364
# Cost after iteration 5140: 0.018328
# Cost after iteration 5150: 0.018291
# Cost after iteration 5160: 0.018254
# Cost after iteration 5170: 0.018218
# Cost after iteration 5180: 0.018181
# Cost after iteration 5190: 0.018145
# Cost after iteration 5200: 0.018109
# Cost after iteration 5210: 0.018073
# Cost after iteration 5220: 0.018038
# Cost after iteration 5230: 0.018002
# Cost after iteration 5240: 0.017967
# Cost after iteration 5250: 0.017931
# Cost after iteration 5260: 0.017896
# Cost after iteration 5270: 0.017861
# Cost after iteration 5280: 0.017826
# Cost after iteration 5290: 0.017791
# Cost after iteration 5300: 0.017757
# Cost after iteration 5310: 0.017722
# Cost after iteration 5320: 0.017688
# Cost after iteration 5330: 0.017654
# Cost after iteration 5340: 0.017619
# Cost after iteration 5350: 0.017585
# Cost after iteration 5360: 0.017552
# Cost after iteration 5370: 0.017518
# Cost after iteration 5380: 0.017484
# Cost after iteration 5390: 0.017451
# Cost after iteration 5400: 0.017417
# Cost after iteration 5410: 0.017384
# Cost after iteration 5420: 0.017351
# Cost after iteration 5430: 0.017318
# Cost after iteration 5440: 0.017285
# Cost after iteration 5450: 0.017253
# Cost after iteration 5460: 0.017220
# Cost after iteration 5470: 0.017188
# Cost after iteration 5480: 0.017155
# Cost after iteration 5490: 0.017123
# Cost after iteration 5500: 0.017091
# Cost after iteration 5510: 0.017059
# Cost after iteration 5520: 0.017027
# Cost after iteration 5530: 0.016995
# Cost after iteration 5540: 0.016964
# Cost after iteration 5550: 0.016932
# Cost after iteration 5560: 0.016901
# Cost after iteration 5570: 0.016869
# Cost after iteration 5580: 0.016838
# Cost after iteration 5590: 0.016807
# Cost after iteration 5600: 0.016776
# Cost after iteration 5610: 0.016745
# Cost after iteration 5620: 0.016715
# Cost after iteration 5630: 0.016684
# Cost after iteration 5640: 0.016653
# Cost after iteration 5650: 0.016623
# Cost after iteration 5660: 0.016593
# Cost after iteration 5670: 0.016563
# Cost after iteration 5680: 0.016533
# Cost after iteration 5690: 0.016503
# Cost after iteration 5700: 0.016473
# Cost after iteration 5710: 0.016443
# Cost after iteration 5720: 0.016413
# Cost after iteration 5730: 0.016384
# Cost after iteration 5740: 0.016354
# Cost after iteration 5750: 0.016325
# Cost after iteration 5760: 0.016296
# Cost after iteration 5770: 0.016267
# Cost after iteration 5780: 0.016238
# Cost after iteration 5790: 0.016209
# Cost after iteration 5800: 0.016180
# Cost after iteration 5810: 0.016151
# Cost after iteration 5820: 0.016123
# Cost after iteration 5830: 0.016094
# Cost after iteration 5840: 0.016066
# Cost after iteration 5850: 0.016037
# Cost after iteration 5860: 0.016009
# Cost after iteration 5870: 0.015981
# Cost after iteration 5880: 0.015953
# Cost after iteration 5890: 0.015925
# Cost after iteration 5900: 0.015897
# Cost after iteration 5910: 0.015870
# Cost after iteration 5920: 0.015842
# Cost after iteration 5930: 0.015815
# Cost after iteration 5940: 0.015787
# Cost after iteration 5950: 0.015760
# Cost after iteration 5960: 0.015733
# Cost after iteration 5970: 0.015705
# Cost after iteration 5980: 0.015678
# Cost after iteration 5990: 0.015651
# Cost after iteration 6000: 0.015624
# Cost after iteration 6010: 0.015598
# Cost after iteration 6020: 0.015571
# Cost after iteration 6030: 0.015544
# Cost after iteration 6040: 0.015518
# Cost after iteration 6050: 0.015491
# Cost after iteration 6060: 0.015465
# Cost after iteration 6070: 0.015439
# Cost after iteration 6080: 0.015413
# Cost after iteration 6090: 0.015387
# Cost after iteration 6100: 0.015361
# Cost after iteration 6110: 0.015335
# Cost after iteration 6120: 0.015309
# Cost after iteration 6130: 0.015283
# Cost after iteration 6140: 0.015258
# Cost after iteration 6150: 0.015232
# Cost after iteration 6160: 0.015207
# Cost after iteration 6170: 0.015181
# Cost after iteration 6180: 0.015156
# Cost after iteration 6190: 0.015131
# Cost after iteration 6200: 0.015106
# Cost after iteration 6210: 0.015080
# Cost after iteration 6220: 0.015055
# Cost after iteration 6230: 0.015031
# Cost after iteration 6240: 0.015006
# Cost after iteration 6250: 0.014981
# Cost after iteration 6260: 0.014956
# Cost after iteration 6270: 0.014932
# Cost after iteration 6280: 0.014907
# Cost after iteration 6290: 0.014883
# Cost after iteration 6300: 0.014859
# Cost after iteration 6310: 0.014834
# Cost after iteration 6320: 0.014810
# Cost after iteration 6330: 0.014786
# Cost after iteration 6340: 0.014762
# Cost after iteration 6350: 0.014738
# Cost after iteration 6360: 0.014714
# Cost after iteration 6370: 0.014691
# Cost after iteration 6380: 0.014667
# Cost after iteration 6390: 0.014643
# Cost after iteration 6400: 0.014620
# Cost after iteration 6410: 0.014596
# Cost after iteration 6420: 0.014573
# Cost after iteration 6430: 0.014549
# Cost after iteration 6440: 0.014526
# Cost after iteration 6450: 0.014503
# Cost after iteration 6460: 0.014480
# Cost after iteration 6470: 0.014457
# Cost after iteration 6480: 0.014434
# Cost after iteration 6490: 0.014411
# Cost after iteration 6500: 0.014388
# Cost after iteration 6510: 0.014365
# Cost after iteration 6520: 0.014343
# Cost after iteration 6530: 0.014320
# Cost after iteration 6540: 0.014298
# Cost after iteration 6550: 0.014275
# Cost after iteration 6560: 0.014253
# Cost after iteration 6570: 0.014230
# Cost after iteration 6580: 0.014208
# Cost after iteration 6590: 0.014186
# Cost after iteration 6600: 0.014164
# Cost after iteration 6610: 0.014142
# Cost after iteration 6620: 0.014120
# Cost after iteration 6630: 0.014098
# Cost after iteration 6640: 0.014076
# Cost after iteration 6650: 0.014054
# Cost after iteration 6660: 0.014033
# Cost after iteration 6670: 0.014011
# Cost after iteration 6680: 0.013989
# Cost after iteration 6690: 0.013968
# Cost after iteration 6700: 0.013946
# Cost after iteration 6710: 0.013925
# Cost after iteration 6720: 0.013904
# Cost after iteration 6730: 0.013883
# Cost after iteration 6740: 0.013861
# Cost after iteration 6750: 0.013840
# Cost after iteration 6760: 0.013819
# Cost after iteration 6770: 0.013798
# Cost after iteration 6780: 0.013777
# Cost after iteration 6790: 0.013756
# Cost after iteration 6800: 0.013736
# Cost after iteration 6810: 0.013715
# Cost after iteration 6820: 0.013694
# Cost after iteration 6830: 0.013673
# Cost after iteration 6840: 0.013653
# Cost after iteration 6850: 0.013632
# Cost after iteration 6860: 0.013612
# Cost after iteration 6870: 0.013592
# Cost after iteration 6880: 0.013571
# Cost after iteration 6890: 0.013551
# Cost after iteration 6900: 0.013531
# Cost after iteration 6910: 0.013511
# Cost after iteration 6920: 0.013491
# Cost after iteration 6930: 0.013471
# Cost after iteration 6940: 0.013451
# Cost after iteration 6950: 0.013431
# Cost after iteration 6960: 0.013411
# Cost after iteration 6970: 0.013391
# Cost after iteration 6980: 0.013371
# Cost after iteration 6990: 0.013352
# Cost after iteration 7000: 0.013332
# Cost after iteration 7010: 0.013313
# Cost after iteration 7020: 0.013293
# Cost after iteration 7030: 0.013274
# Cost after iteration 7040: 0.013254
# Cost after iteration 7050: 0.013235
# Cost after iteration 7060: 0.013216
# Cost after iteration 7070: 0.013196
# Cost after iteration 7080: 0.013177
# Cost after iteration 7090: 0.013158
# Cost after iteration 7100: 0.013139
# Cost after iteration 7110: 0.013120
# Cost after iteration 7120: 0.013101
# Cost after iteration 7130: 0.013082
# Cost after iteration 7140: 0.013063
# Cost after iteration 7150: 0.013045
# Cost after iteration 7160: 0.013026
# Cost after iteration 7170: 0.013007
# Cost after iteration 7180: 0.012989
# Cost after iteration 7190: 0.012970
# Cost after iteration 7200: 0.012952
# Cost after iteration 7210: 0.012933
# Cost after iteration 7220: 0.012915
# Cost after iteration 7230: 0.012896
# Cost after iteration 7240: 0.012878
# Cost after iteration 7250: 0.012860
# Cost after iteration 7260: 0.012842
# Cost after iteration 7270: 0.012823
# Cost after iteration 7280: 0.012805
# Cost after iteration 7290: 0.012787
# Cost after iteration 7300: 0.012769
# Cost after iteration 7310: 0.012751
# Cost after iteration 7320: 0.012733
# Cost after iteration 7330: 0.012716
# Cost after iteration 7340: 0.012698
# Cost after iteration 7350: 0.012680
# Cost after iteration 7360: 0.012662
# Cost after iteration 7370: 0.012645
# Cost after iteration 7380: 0.012627
# Cost after iteration 7390: 0.012610
# Cost after iteration 7400: 0.012592
# Cost after iteration 7410: 0.012575
# Cost after iteration 7420: 0.012557
# Cost after iteration 7430: 0.012540
# Cost after iteration 7440: 0.012522
# Cost after iteration 7450: 0.012505
# Cost after iteration 7460: 0.012488
# Cost after iteration 7470: 0.012471
# Cost after iteration 7480: 0.012454
# Cost after iteration 7490: 0.012437
# Cost after iteration 7500: 0.012420
# Cost after iteration 7510: 0.012403
# Cost after iteration 7520: 0.012386
# Cost after iteration 7530: 0.012369
# Cost after iteration 7540: 0.012352
# Cost after iteration 7550: 0.012335
# Cost after iteration 7560: 0.012318
# Cost after iteration 7570: 0.012302
# Cost after iteration 7580: 0.012285
# Cost after iteration 7590: 0.012268
# Cost after iteration 7600: 0.012252
# Cost after iteration 7610: 0.012235
# Cost after iteration 7620: 0.012219
# Cost after iteration 7630: 0.012202
# Cost after iteration 7640: 0.012186
# Cost after iteration 7650: 0.012170
# Cost after iteration 7660: 0.012153
# Cost after iteration 7670: 0.012137
# Cost after iteration 7680: 0.012121
# Cost after iteration 7690: 0.012105
# Cost after iteration 7700: 0.012088
# Cost after iteration 7710: 0.012072
# Cost after iteration 7720: 0.012056
# Cost after iteration 7730: 0.012040
# Cost after iteration 7740: 0.012024
# Cost after iteration 7750: 0.012008
# Cost after iteration 7760: 0.011992
# Cost after iteration 7770: 0.011977
# Cost after iteration 7780: 0.011961
# Cost after iteration 7790: 0.011945
# Cost after iteration 7800: 0.011929
# Cost after iteration 7810: 0.011914
# Cost after iteration 7820: 0.011898
# Cost after iteration 7830: 0.011882
# Cost after iteration 7840: 0.011867
# Cost after iteration 7850: 0.011851
# Cost after iteration 7860: 0.011836
# Cost after iteration 7870: 0.011820
# Cost after iteration 7880: 0.011805
# Cost after iteration 7890: 0.011790
# Cost after iteration 7900: 0.011774
# Cost after iteration 7910: 0.011759
# Cost after iteration 7920: 0.011744
# Cost after iteration 7930: 0.011729
# Cost after iteration 7940: 0.011713
# Cost after iteration 7950: 0.011698
# Cost after iteration 7960: 0.011683
# Cost after iteration 7970: 0.011668
# Cost after iteration 7980: 0.011653
# Cost after iteration 7990: 0.011638
# Cost after iteration 8000: 0.011623
# Cost after iteration 8010: 0.011608
# Cost after iteration 8020: 0.011594
# Cost after iteration 8030: 0.011579
# Cost after iteration 8040: 0.011564
# Cost after iteration 8050: 0.011549
# Cost after iteration 8060: 0.011535
# Cost after iteration 8070: 0.011520
# Cost after iteration 8080: 0.011505
# Cost after iteration 8090: 0.011491
# Cost after iteration 8100: 0.011476
# Cost after iteration 8110: 0.011462
# Cost after iteration 8120: 0.011447
# Cost after iteration 8130: 0.011433
# Cost after iteration 8140: 0.011418
# Cost after iteration 8150: 0.011404
# Cost after iteration 8160: 0.011389
# Cost after iteration 8170: 0.011375
# Cost after iteration 8180: 0.011361
# Cost after iteration 8190: 0.011347
# Cost after iteration 8200: 0.011332
# Cost after iteration 8210: 0.011318
# Cost after iteration 8220: 0.011304
# Cost after iteration 8230: 0.011290
# Cost after iteration 8240: 0.011276
# Cost after iteration 8250: 0.011262
# Cost after iteration 8260: 0.011248
# Cost after iteration 8270: 0.011234
# Cost after iteration 8280: 0.011220
# Cost after iteration 8290: 0.011206
# Cost after iteration 8300: 0.011192
# Cost after iteration 8310: 0.011179
# Cost after iteration 8320: 0.011165
# Cost after iteration 8330: 0.011151
# Cost after iteration 8340: 0.011137
# Cost after iteration 8350: 0.011124
# Cost after iteration 8360: 0.011110
# Cost after iteration 8370: 0.011096
# Cost after iteration 8380: 0.011083
# Cost after iteration 8390: 0.011069
# Cost after iteration 8400: 0.011056
# Cost after iteration 8410: 0.011042
# Cost after iteration 8420: 0.011029
# Cost after iteration 8430: 0.011015
# Cost after iteration 8440: 0.011002
# Cost after iteration 8450: 0.010989
# Cost after iteration 8460: 0.010975
# Cost after iteration 8470: 0.010962
# Cost after iteration 8480: 0.010949
# Cost after iteration 8490: 0.010936
# Cost after iteration 8500: 0.010922
# Cost after iteration 8510: 0.010909
# Cost after iteration 8520: 0.010896
# Cost after iteration 8530: 0.010883
# Cost after iteration 8540: 0.010870
# Cost after iteration 8550: 0.010857
# Cost after iteration 8560: 0.010844
# Cost after iteration 8570: 0.010831
# Cost after iteration 8580: 0.010818
# Cost after iteration 8590: 0.010805
# Cost after iteration 8600: 0.010792
# Cost after iteration 8610: 0.010779
# Cost after iteration 8620: 0.010767
# Cost after iteration 8630: 0.010754
# Cost after iteration 8640: 0.010741
# Cost after iteration 8650: 0.010728
# Cost after iteration 8660: 0.010716
# Cost after iteration 8670: 0.010703
# Cost after iteration 8680: 0.010690
# Cost after iteration 8690: 0.010678
# Cost after iteration 8700: 0.010665
# Cost after iteration 8710: 0.010653
# Cost after iteration 8720: 0.010640
# Cost after iteration 8730: 0.010628
# Cost after iteration 8740: 0.010615
# Cost after iteration 8750: 0.010603
# Cost after iteration 8760: 0.010590
# Cost after iteration 8770: 0.010578
# Cost after iteration 8780: 0.010565
# Cost after iteration 8790: 0.010553
# Cost after iteration 8800: 0.010541
# Cost after iteration 8810: 0.010529
# Cost after iteration 8820: 0.010516
# Cost after iteration 8830: 0.010504
# Cost after iteration 8840: 0.010492
# Cost after iteration 8850: 0.010480
# Cost after iteration 8860: 0.010468
# Cost after iteration 8870: 0.010456
# Cost after iteration 8880: 0.010444
# Cost after iteration 8890: 0.010432
# Cost after iteration 8900: 0.010420
# Cost after iteration 8910: 0.010408
# Cost after iteration 8920: 0.010396
# Cost after iteration 8930: 0.010384
# Cost after iteration 8940: 0.010372
# Cost after iteration 8950: 0.010360
# Cost after iteration 8960: 0.010348
# Cost after iteration 8970: 0.010336
# Cost after iteration 8980: 0.010324
# Cost after iteration 8990: 0.010313
# Cost after iteration 9000: 0.010301
# Cost after iteration 9010: 0.010289
# Cost after iteration 9020: 0.010278
# Cost after iteration 9030: 0.010266
# Cost after iteration 9040: 0.010254
# Cost after iteration 9050: 0.010243
# Cost after iteration 9060: 0.010231
# Cost after iteration 9070: 0.010219
# Cost after iteration 9080: 0.010208
# Cost after iteration 9090: 0.010196
# Cost after iteration 9100: 0.010185
# Cost after iteration 9110: 0.010174
# Cost after iteration 9120: 0.010162
# Cost after iteration 9130: 0.010151
# Cost after iteration 9140: 0.010139
# Cost after iteration 9150: 0.010128
# Cost after iteration 9160: 0.010117
# Cost after iteration 9170: 0.010105
# Cost after iteration 9180: 0.010094
# Cost after iteration 9190: 0.010083
# Cost after iteration 9200: 0.010072
# Cost after iteration 9210: 0.010060
# Cost after iteration 9220: 0.010049
# Cost after iteration 9230: 0.010038
# Cost after iteration 9240: 0.010027
# Cost after iteration 9250: 0.010016
# Cost after iteration 9260: 0.010005
# Cost after iteration 9270: 0.009994
# Cost after iteration 9280: 0.009983
# Cost after iteration 9290: 0.009972
# Cost after iteration 9300: 0.009961
# Cost after iteration 9310: 0.009950
# Cost after iteration 9320: 0.009939
# Cost after iteration 9330: 0.009928
# Cost after iteration 9340: 0.009917
# Cost after iteration 9350: 0.009906
# Cost after iteration 9360: 0.009895
# Cost after iteration 9370: 0.009884
# Cost after iteration 9380: 0.009874
# Cost after iteration 9390: 0.009863
# Cost after iteration 9400: 0.009852
# Cost after iteration 9410: 0.009841
# Cost after iteration 9420: 0.009831
# Cost after iteration 9430: 0.009820
# Cost after iteration 9440: 0.009809
# Cost after iteration 9450: 0.009799
# Cost after iteration 9460: 0.009788
# Cost after iteration 9470: 0.009778
# Cost after iteration 9480: 0.009767
# Cost after iteration 9490: 0.009756
# Cost after iteration 9500: 0.009746
# Cost after iteration 9510: 0.009735
# Cost after iteration 9520: 0.009725
# Cost after iteration 9530: 0.009715
# Cost after iteration 9540: 0.009704
# Cost after iteration 9550: 0.009694
# Cost after iteration 9560: 0.009683
# Cost after iteration 9570: 0.009673
# Cost after iteration 9580: 0.009663
# Cost after iteration 9590: 0.009652
# Cost after iteration 9600: 0.009642
# Cost after iteration 9610: 0.009632
# Cost after iteration 9620: 0.009622
# Cost after iteration 9630: 0.009611
# Cost after iteration 9640: 0.009601
# Cost after iteration 9650: 0.009591
# Cost after iteration 9660: 0.009581
# Cost after iteration 9670: 0.009571
# Cost after iteration 9680: 0.009560
# Cost after iteration 9690: 0.009550
# Cost after iteration 9700: 0.009540
# Cost after iteration 9710: 0.009530
# Cost after iteration 9720: 0.009520
# Cost after iteration 9730: 0.009510
# Cost after iteration 9740: 0.009500
# Cost after iteration 9750: 0.009490
# Cost after iteration 9760: 0.009480
# Cost after iteration 9770: 0.009470
# Cost after iteration 9780: 0.009460
# Cost after iteration 9790: 0.009451
# Cost after iteration 9800: 0.009441
# Cost after iteration 9810: 0.009431
# Cost after iteration 9820: 0.009421
# Cost after iteration 9830: 0.009411
# Cost after iteration 9840: 0.009401
# Cost after iteration 9850: 0.009392
# Cost after iteration 9860: 0.009382
# Cost after iteration 9870: 0.009372
# Cost after iteration 9880: 0.009362
# Cost after iteration 9890: 0.009353
# Cost after iteration 9900: 0.009343
# Cost after iteration 9910: 0.009333
# Cost after iteration 9920: 0.009324
# Cost after iteration 9930: 0.009314
# Cost after iteration 9940: 0.009305
# Cost after iteration 9950: 0.009295
# Cost after iteration 9960: 0.009286
# Cost after iteration 9970: 0.009276
# Cost after iteration 9980: 0.009266
# Cost after iteration 9990: 0.009257
# ({'b': 11.109354876413665, 'w': array([[ 1.68242001],
#          [-6.94180993]])},
#  {'db': -0.0027302901451890659, 'dw': array([[-0.00044453],
#          [ 0.00169188]])},
#  [0.80773563377124158,
#   0.71576113709997291,
#   0.67825502224964218,
#   0.65036935416962849,
#   0.62564560763998556,
#   0.60270832459849277,
#   0.58111403599282174,
#   0.56067210105567622,
#   0.5412778701426797,
#   0.52285919713812723,
#   0.50535733965701835,
#   0.48871993255027146,
#   0.47289839834710251,
#   0.45784699430799841,
#   0.44352245210293839,
#   0.42988382268501235,
#   0.41689238522306971,
#   0.40451157071587984,
#   0.39270688458588482,
#   0.38144582455351805,
#   0.37069779410552639,
#   0.36043401299754591,
#   0.35062742635799427,
#   0.34125261377299854,
#   0.33228569947321596,
#   0.32370426449401762,
#   0.315487261463755,
#   0.30761493249408783,
#   0.30006873049862215,
#   0.29283124414693618,
#   0.28588612656596624,
#   0.2792180278256946,
#   0.27281253118766424,
#   0.26665609305011362,
#   0.26073598648999174,
#   0.25504024827770455,
#   0.2495576292233907,
#   0.24427754770239254,
#   0.23919004620114781,
#   0.2342857507219876,
#   0.22955583288544693,
#   0.22499197457102396,
#   0.22058633494128693,
#   0.21633151969939324,
#   0.21222055243609733,
#   0.20824684792888704,
#   0.20440418726277665,
#   0.20068669464934202,
#   0.19708881582763774,
#   0.19360529793760986,
#   0.19023117076343432,
#   0.18696172925078031,
#   0.18379251720833323,
#   0.18071931210992689,
#   0.17773811091937111,
#   0.17484511686546478,
#   0.17203672709978116,
#   0.16930952117460429,
#   0.16666025028286785,
#   0.16408582720615039,
#   0.16158331692067629,
#   0.1591499278149236,
#   0.156783003475817,
#   0.15448001500363731,
#   0.15223855381869075,
#   0.15005632492549786,
#   0.14793114060276316,
#   0.14586091448971655,
#   0.1438436560415656,
#   0.14187746532879142,
#   0.13996052815686102,
#   0.13809111148463477,
#   0.13626755912132288,
#   0.13448828768330071,
#   0.13275178279344182,
#   0.13105659550687293,
#   0.12940133894820699,
#   0.12778468514637609,
#   0.12620536205417099,
#   0.12466215074050702,
#   0.12315388274427674,
#   0.12167943757943385,
#   0.12023774038167059,
#   0.11882775968772363,
#   0.11744850533896159,
#   0.11609902650147627,
#   0.11477840979544207,
#   0.11348577752698531,
#   0.11222028601627616,
#   0.1109811240159706,
#   0.10976751121452441,
#   0.10857869681926771,
#   0.1074139582144652,
#   0.10627259968990094,
#   0.10515395123582078,
#   0.10405736740033356,
#   0.10298222620562787,
#   0.10192792811959218,
#   0.10089389507964748,
#   0.099879569565802018,
#   0.098884413720127864,
#   0.097907908510036751,
#   0.096949552932892508,
#   0.096008863259653993,
#   0.095085372315384109,
#   0.094178628794592045,
#   0.093288196609501328,
#   0.092413654269452639,
#   0.091554594289755431,
#   0.090710622628408136,
#   0.089881358149196025,
#   0.089066432109768112,
#   0.088265487673375831,
#   0.087478179443031684,
#   0.086704173016920308,
#   0.085943144563962487,
#   0.085194780418493599,
#   0.084458776693079857,
#   0.083734838908549741,
#   0.083022681640371188,
#   0.082322028180553314,
#   0.081632610214298157,
#   0.080954167510670083,
#   0.080286447626591845,
#   0.079629205623513985,
#   0.078982203796140016,
#   0.078345211412622365,
#   0.077718004465678781,
#   0.077100365434104312,
#   0.076492083054184645,
#   0.075892952100543878,
#   0.075302773175979582,
#   0.074721352509869388,
#   0.074148501764745176,
#   0.073584037850663281,
#   0.073027782747006442,
#   0.072479563331382016,
#   0.071939211215292842,
#   0.071406562586273731,
#   0.070881458056203855,
#   0.070363742515520106,
#   0.06985326499306671,
#   0.069349878521334729,
#   0.068853440006853076,
#   0.068363810105506767,
#   0.067880853102567057,
#   0.067404436797231793,
#   0.066934432391480392,
#   0.066470714383059779,
#   0.066013160462426057,
#   0.065561651413473282,
#   0.065116071017891658,
#   0.064676305963002723,
#   0.064242245752925642,
#   0.063813782622939658,
#   0.063390811456907351,
#   0.062973229707636733,
#   0.062560937320060364,
#   0.06215383665711792,
#   0.061751832428233913,
#   0.06135483162028519,
#   0.06096274343095931,
#   0.060575479204410185,
#   0.060192952369118216,
#   0.059815078377869535,
#   0.05944177464977133,
#   0.059072960514224102,
#   0.058708557156774033,
#   0.058348487566775804,
#   0.057992676486793029,
#   0.057641050363672286,
#   0.057293537301227195,
#   0.056950067014470897,
#   0.056610570785338495,
#   0.056274981419845771,
#   0.055943233206628404,
#   0.055615261876811518,
#   0.055291004565161596,
#   0.054970399772471513,
#   0.054653387329135911,
#   0.054339908359871715,
#   0.054029905249544652,
#   0.053723321610060007,
#   0.053420102248279588,
#   0.053120193134930695,
#   0.052823541374468611,
#   0.052530095175861137,
#   0.052239803824262618,
#   0.051952617653545231,
#   0.051668488019658405,
#   0.051387367274788355,
#   0.051109208742288484,
#   0.050833966692355723,
#   0.050561596318426619,
#   0.050292053714268106,
#   0.050025295851741265,
#   0.049761280559213097,
#   0.049499966500595946,
#   0.049241313154993506,
#   0.048985280796932741,
#   0.048731830477162966,
#   0.048480924004002009,
#   0.048232523925213308,
#   0.047986593510395761,
#   0.047743096733869103,
#   0.047501998258039115,
#   0.047263263417227794,
#   0.047026858201953438,
#   0.04679274924364378,
#   0.046560903799773165,
#   0.046331289739405937,
#   0.046103875529134836,
#   0.045878630219402805,
#   0.045655523431194563,
#   0.045434525343087562,
#   0.045215606678651155,
#   0.044998738694182,
#   0.044783893166767189,
#   0.044571042382662941,
#   0.04436015912598161,
#   0.044151216667674992,
#   0.043944188754807587,
#   0.043739049600108396,
#   0.04353577387179558,
#   0.043334336683663627,
#   0.043134713585426143,
#   0.042936880553306862,
#   0.042740813980870936,
#   0.042546490670089948,
#   0.042353887822633537,
#   0.042162983031380746,
#   0.041973754272145426,
#   0.041786179895608573,
#   0.041600238619452432,
#   0.041415909520690256,
#   0.041233172028185265,
#   0.041052005915355877,
#   0.040872391293058155,
#   0.040694308602644037,
#   0.040517738609188281,
#   0.040342662394880019,
#   0.04016906135257442,
#   0.039996917179499193,
#   0.039826211871113654,
#   0.03965692771511279,
#   0.039489047285575979,
#   0.039322553437253743,
#   0.039157429299989929,
#   0.038993658273275063,
#   0.038831224020928146,
#   0.038670110465902546,
#   0.0385103017852131,
#   0.038351782404980501,
#   0.038194536995591208,
#   0.038038550466968579,
#   0.037883807963951965,
#   0.037730294861782754,
#   0.037577996761692302,
#   0.037426899486591093,
#   0.037276989076854186,
#   0.037128251786203027,
#   0.036980674077679312,
#   0.036834242619708808,
#   0.036688944282252965,
#   0.036544766133047149,
#   0.03640169543392055,
#   0.036259719637199053,
#   0.036118826382185922,
#   0.035979003491720347,
#   0.035840238968811264,
#   0.035702520993344318,
#   0.035565837918859478,
#   0.035430178269400397,
#   0.035295530736429298,
#   0.035161884175809635,
#   0.035029227604852962,
#   0.034897550199428758,
#   0.034766841291135726,
#   0.034637090364532691,
#   0.034508287054428634,
#   0.034380421143229409,
#   0.034253482558339834,
#   0.034127461369620554,
#   0.034002347786897813,
#   0.033878132157524651,
#   0.033754804963993093,
#   0.033632356821594538,
#   0.03351077847612996,
#   0.033390060801665546,
#   0.033270194798334408,
#   0.033151171590184277,
#   0.033032982423067098,
#   0.032915618662572393,
#   0.032799071792002407,
#   0.032683333410387372,
#   0.032568395230540795,
#   0.032454249077153496,
#   0.032340886884926118,
#   0.032228300696737502,
#   0.032116482661851159,
#   0.03200542503415453,
#   0.031895120170435748,
#   0.031785560528691817,
#   0.031676738666471027,
#   0.031568647239247877,
#   0.031461278998828231,
#   0.031354626791786452,
#   0.031248683557932977,
#   0.031143442328809796,
#   0.031038896226216535,
#   0.030935038460763904,
#   0.030831862330454068,
#   0.030729361219289771,
#   0.030627528595907366,
#   0.030526358012238193,
#   0.030425843102193668,
#   0.030325977580374759,
#   0.030226755240806903,
#   0.030128169955697497,
#   0.030030215674216935,
#   0.029932886421302145,
#   0.029836176296481942,
#   0.029740079472725091,
#   0.029644590195308008,
#   0.029549702780704293,
#   0.029455411615494718,
#   0.02936171115529582,
#   0.029268595923709513,
#   0.02917606051129034,
#   0.029084099574532358,
#   0.028992707834874221,
#   0.028901880077721032,
#   0.02881161115148537,
#   0.028721895966644186,
#   0.028632729494812499,
#   0.028544106767834788,
#   0.028456022876890932,
#   0.028368472971618743,
#   0.028281452259252125,
#   0.028194956003773464,
#   0.02810897952508196,
#   0.028023518198175577,
#   0.027938567452347851,
#   0.02785412277039806,
#   0.027770179687855934,
#   0.027686733792218449,
#   0.027603780722200953,
#   0.027521316167000855,
#   0.027439335865573337,
#   0.02735783560592004,
#   0.027276811224389828,
#   0.027196258604990885,
#   0.027116173678714984,
#   0.027036552422873429,
#   0.026957390860442954,
#   0.026878685059423923,
#   0.026800431132209052,
#   0.026722625234961404,
#   0.02664526356700481,
#   0.026568342370222736,
#   0.026491857928467637,
#   0.026415806566980657,
#   0.026340184651819712,
#   0.026264988589298197,
#   0.026190214825432045,
#   0.026115859845396081,
#   0.026041920172989411,
#   0.025968392370109134,
#   0.025895273036233291,
#   0.025822558807911226,
#   0.025750246358262844,
#   0.025678332396485662,
#   0.025606813667369922,
#   0.025535686950821319,
#   0.025464949061391701,
#   0.025394596847816468,
#   0.025324627192560296,
#   0.025255037011369066,
#   0.02518582325283001,
#   0.025116982897937724,
#   0.025048512959667455,
#   0.02498041048255531,
#   0.024912672542284648,
#   0.024845296245279147,
#   0.024778278728302256,
#   0.024711617158062228,
#   0.024645308730824506,
#   0.024579350672028811,
#   0.024513740235913205,
#   0.024448474705142862,
#   0.024383551390445395,
#   0.024318967630251778,
#   0.024254720790341751,
#   0.024190808263496094,
#   0.024127227469152412,
#   0.024063975853068222,
#   0.02400105088698723,
#   0.023938450068311586,
#   0.023876170919779314,
#   0.023814210989145674,
#   0.023752567848869921,
#   0.023691239095806938,
#   0.02363022235090282,
#   0.023569515258895286,
#   0.02350911548801863,
#   0.023449020729713062,
#   0.023389228698338097,
#   0.023329737130890371,
#   0.023270543786725148,
#   0.023211646447282869,
#   0.02315304291581869,
#   0.023094731017136577,
#   0.023036708597326722,
#   0.022978973523507685,
#   0.02292152368357105,
#   0.022864356985930871,
#   0.022807471359276011,
#   0.02275086475232645,
#   0.022694535133592847,
#   0.022638480491139562,
#   0.022582698832351283,
#   0.02252718818370256,
#   0.022471946590531221,
#   0.022416972116814263,
#   0.022362262844947651,
#   0.022307816875528554,
#   0.022253632327141011,
#   0.022199707336145031,
#   0.022146040056467246,
#   0.022092628659396304,
#   0.022039471333379718,
#   0.021986566283824123,
#   0.021933911732898607,
#   0.021881505919339794,
#   0.021829347098260458,
#   0.021777433540960889,
#   0.02172576353474219,
#   0.021674335382722135,
#   0.021623147403654414,
#   0.021572197931749644,
#   0.021521485316498841,
#   0.02147100792249973,
#   0.021420764129284373,
#   0.02137075233115112,
#   0.021320970936996107,
#   0.021271418370149914,
#   0.021222093068214029,
#   0.021172993482900831,
#   0.021124118079875423,
#   0.021075465338599594,
#   0.021027033752177585,
#   0.02097882182720421,
#   0.020930828083615072,
#   0.020883051054538256,
#   0.020835489286148902,
#   0.020788141337524428,
#   0.020741005780502895,
#   0.020694081199542632,
#   0.020647366191583333,
#   0.020600859365910038,
#   0.020554559344017787,
#   0.02050846475947864,
#   0.020462574257810742,
#   0.020416886496347632,
#   0.020371400144111221,
#   0.020326113881684954,
#   0.020281026401089371,
#   0.020236136405658744,
#   0.020191442609919685,
#   0.020146943739471124,
#   0.020102638530865982,
#   0.020058525731494109,
#   0.020014604099466822,
#   0.019970872403503297,
#   0.019927329422817434,
#   0.019883973947007184,
#   0.019840804775945048,
#   0.019797820719668961,
#   0.019755020598276336,
#   0.019712403241817777,
#   0.019669967490192775,
#   0.019627712193047368,
#   0.019585636209671797,
#   0.019543738408900294,
#   0.019502017669011766,
#   0.019460472877632386,
#   0.019419102931638059,
#   0.019377906737059268,
#   0.019336883208986952,
#   0.019296031271478824,
#   0.019255349857467678,
#   0.019214837908670138,
#   0.019174494375497151,
#   0.019134318216964923,
#   0.019094308400607655,
#   0.019054463902390538,
#   0.01901478370662469,
#   0.018975266805882216,
#   0.018935912200913042,
#   0.018896718900562354,
#   0.018857685921688849,
#   0.018818812289084816,
#   0.018780097035395998,
#   0.018741539201043551,
#   0.018703137834145935,
#   0.018664891990442484,
#   0.0186268007332175,
#   0.018588863133225379,
#   0.018551078268616593,
#   0.018513445224864394,
#   0.018475963094692977,
#   0.018438630978005341,
#   0.018401447981813659,
#   0.018364413220168366,
#   0.01832752581409024,
#   0.01829078489150179,
#   0.018254189587159755,
#   0.018217739042589019,
#   0.018181432406016485,
#   0.018145268832306195,
#   0.018109247482894719,
#   0.018073367525728537,
#   0.018037628135200094,
#   0.018002028492086444,
#   0.017966567783487875,
#   0.017931245202766889,
#   0.017896059949488605,
#   0.017861011229361245,
#   0.017826098254177861,
#   0.017791320241757919,
#   0.01775667641589046,
#   0.017722166006277396,
#   0.017687788248477321,
#   0.017653542383850279,
#   0.017619427659503268,
#   0.017585443328235747,
#   0.017551588648486369,
#   0.017517862884279964,
#   0.017484265305175661,
#   0.017450795186214382,
#   0.017417451807868346,
#   0.01738423445599022,
#   0.017351142421763346,
#   0.017318175001651906,
#   0.017285331497352292,
#   0.017252611215744784,
#   0.017220013468845538,
#   0.017187537573759092,
#   0.017155182852632241,
#   0.017122948632607188,
#   0.017090834245775802,
#   0.017058839029134777,
#   0.017026962324540405,
#   0.016995203478664324,
#   0.01696356184295026,
#   0.01693203677356999,
#   0.016900627631380977,
#   0.016869333781883818,
#   0.016838154595180017,
#   0.016807089445931182,
#   0.016776137713317332,
#   0.016745298780996641,
#   0.016714572037065153,
#   0.016683956874017414,
#   0.016653452688706299,
#   0.016623058882305274,
#   0.016592774860268875,
#   0.016562600032295316,
#   0.016532533812288853,
#   0.016502575618321913,
#   0.016472724872598862,
#   0.016442981001419193,
#   0.016413343435141683,
#   0.016383811608148311,
#   0.016354384958809327,
#   0.016325062929447992,
#   0.016295844966306337,
#   0.016266730519510317,
#   0.01623771904303669,
#   0.016208809994678778,
#   0.01618000283601392,
#   0.016151297032369998,
#   0.016122692052793673,
#   0.016094187370017599,
#   0.016065782460428751,
#   0.016037476804037214,
#   0.016009269884444816,
#   0.015981161188814229,
#   0.015953150207838454,
#   0.015925236435710633,
#   0.01589741937009408,
#   0.015869698512092925,
#   0.015842073366222287,
#   0.015814543440379861,
#   0.015787108245816833,
#   0.015759767297109636,
#   0.015732520112131491,
#   0.015705366212025056,
#   0.015678305121174629,
#   0.015651336367178373,
#   0.015624459480822342,
#   0.015597673996053,
#   0.015570979449950473,
#   0.015544375382703427,
#   0.015517861337581849,
#   0.015491436860912325,
#   0.015465101502052013,
#   0.015438854813363968,
#   0.015412696350191529,
#   0.015386625670834439,
#   0.015360642336523492,
#   0.015334745911397371,
#   0.015308935962477885,
#   0.015283212059646435,
#   0.015257573775620781,
#   0.015232020685931311,
#   0.015206552368898585,
#   0.015181168405610077,
#   0.015155868379897797,
#   0.015130651878315884,
#   0.015105518490118272,
#   0.015080467807237277,
#   0.01505549942426106,
#   0.015030612938413054,
#   0.01500580794952994,
#   0.014981084060040834,
#   0.014956440874946374,
#   0.014931878001798024,
#   0.014907395050677808,
#   0.014882991634177375,
#   0.014858667367378536,
#   0.014834421867833351,
#   0.014810254755543756,
#   0.014786165652942763,
#   0.014762154184874775,
#   0.014738219978576533,
#   0.014714362663657799,
#   0.014690581872083282,
#   0.014666877238153152,
#   0.014643248398485353,
#   0.014619694991996814,
#   0.014596216659885386,
#   0.014572813045612545,
#   0.014549483794884667,
#   0.014526228555636261,
#   0.014503046978011969,
#   0.0144799387143496,
#   0.014456903419162928,
#   0.014433940749124873,
#   0.014411050363050588,
#   0.014388231921880735,
#   0.0143654850886654,
#   0.014342809528547072,
#   0.014320204908745405,
#   0.014297670898540222,
#   0.014275207169256499,
#   0.014252813394247856,
#   0.01423048924888173,
#   0.014208234410523166,
#   0.014186048558520296,
#   0.01416393137418856,
#   0.014141882540795883,
#   0.014119901743547986,
#   0.01409798866957325,
#   0.01407614300790859,
#   0.014054364449484444,
#   0.014032652687110925,
#   0.014011007415463234,
#   0.013989428331067611,
#   0.013967915132287578,
#   0.013946467519309825,
#   0.013925085194130828,
#   0.013903767860542949,
#   0.013882515224121166,
#   0.013861326992209553,
#   0.013840202873908185,
#   0.013819142580059904,
#   0.013798145823237672,
#   0.013777212317730957,
#   0.013756341779534019,
#   0.013735533926332259,
#   0.013714788477490235,
#   0.013694105154038985,
#   0.01367348367866407,
#   0.013652923775693044,
#   0.013632425171083172,
#   0.013611987592410073,
#   0.013591610768855289,
#   0.013571294431194448,
#   0.013551038311786237,
#   0.013530842144559971,
#   0.013510705665004973,
#   0.013490628610158395,
#   0.013470610718594333,
#   0.013450651730412733,
#   0.013430751387228195,
#   0.013410909432159142,
#   0.01339112560981621,
#   0.013371399666292551,
#   0.013351731349152584,
#   0.013332120407421053,
#   0.013312566591573007,
#   0.013293069653523393,
#   0.013273629346616328,
#   0.013254245425614902,
#   0.013234917646691633,
#   0.013215645767417614,
#   0.01319642954675268,
#   0.013177268745036073,
#   0.013158163123975978,
#   0.01313911244663998,
#   0.013120116477445655,
#   0.013101174982150599,
#   0.013082287727843056,
#   0.013063454482932843,
#   0.01304467501714158,
#   0.013025949101493777,
#   0.013007276508307353,
#   0.012988657011184592,
#   0.012970090385003685,
#   0.012951576405908794,
#   0.012933114851301908,
#   0.012914705499833871,
#   0.012896348131395691,
#   0.012878042527109801,
#   0.012859788469321504,
#   0.012841585741590378,
#   0.012823434128682202,
#   0.012805333416560091,
#   0.012787283392376631,
#   0.012769283844465358,
#   0.012751334562332762,
#   0.012733435336650063,
#   0.012715585959245428,
#   0.012697786223095784,
#   0.012680035922318944,
#   0.012662334852165863,
#   0.012644682809012842,
#   0.012627079590353906,
#   0.012609524994793016,
#   0.012592018822036548,
#   0.012574560872885792,
#   0.012557150949229644,
#   0.012539788854036935,
#   0.012522474391349337,
#   0.012505207366273974,
#   0.012487987584976165,
#   0.012470814854672468,
#   0.012453688983623392,
#   0.012436609781126451,
#   0.012419577057509021,
#   0.012402590624121664,
#   0.012385650293331387,
#   0.012368755878513911,
#   0.012351907194048422,
#   0.012335104055309371,
#   0.01231834627866072,
#   0.012301633681449004,
#   0.012284966081997185,
#   0.012268343299597369,
#   0.012251765154505184,
#   0.012235231467932893,
#   0.012218742062043309,
#   0.012202296759943488,
#   0.012185895385678023,
#   0.012169537764223668,
#   0.012153223721482323,
#   0.012136953084275877,
#   0.012120725680339251,
#   0.0121045413383149,
#   0.01208839988774698,
#   0.012072301159074983,
#   0.012056244983628159,
#   0.012040231193619803,
#   0.012024259622141202,
#   0.012008330103156148,
#   0.011992442471495186,
#   0.01197659656284988,
#   0.011960792213767538,
#   0.011945029261644993,
#   0.011929307544724155,
#   0.011913626902085438,
#   0.011897987173642989,
#   0.011882388200139333,
#   0.011866829823139673,
#   0.011851311885026883,
#   0.011835834228996112,
#   0.011820396699049638,
#   0.011804999139991824,
#   0.011789641397423528,
#   0.011774323317737758,
#   0.011759044748113729,
#   0.011743805536512584,
#   0.011728605531672093,
#   0.011713444583101551,
#   0.011698322541077343,
#   0.011683239256637654,
#   0.011668194581577926,
#   0.011653188368445611,
#   0.011638220470536226,
#   0.01162329074188781,
#   0.011608399037276522,
#   0.011593545212212316,
#   0.011578729122933938,
#   0.011563950626404246,
#   0.01154920958030629,
#   0.01153450584303805,
#   0.011519839273708548,
#   0.011505209732132995,
#   0.011490617078828584,
#   0.01147606117501008,
#   0.011461541882585519,
#   0.011447059064151763,
#   0.011432612582990373,
#   0.0114182023030634,
#   0.01140382808900875,
#   0.011389489806136507,
#   0.011375187320424697,
#   0.011360920498514832,
#   0.011346689207708135,
#   0.011332493315961223,
#   0.011318332691882706,
#   0.011304207204727884,
#   0.011290116724396214,
#   0.011276061121426735,
#   0.011262040266993992,
#   0.011248054032904126,
#   0.011234102291591479,
#   0.011220184916114513,
#   0.011206301780151844,
#   0.011192452757998492,
#   0.011178637724562717,
#   0.011164856555361181,
#   0.011151109126516375,
#   0.011137395314752351,
#   0.011123714997391152,
#   0.011110068052349317,
#   0.01109645435813412,
#   0.01108287379384046,
#   0.011069326239146438,
#   0.011055811574310905,
#   0.011042329680169192,
#   0.011028880438130041,
#   0.011015463730171954,
#   0.011002079438839817,
#   0.010988727447241957,
#   0.010975407639045929,
#   0.01096211989847597,
#   0.010948864110309217,
#   0.010935640159872483,
#   0.010922447933039415,
#   0.010909287316226524,
#   0.01089615819639056,
#   0.010883060461024961,
#   0.01086999399815697,
#   0.010856958696344234,
#   0.01084395444467184,
#   0.010830981132749004,
#   0.010818038650706166,
#   0.010805126889192067,
#   0.010792245739370172,
#   0.010779395092916146,
#   0.010766574842014787,
#   0.010753784879356854,
#   0.010741025098136322,
#   0.010728295392047055,
#   0.010715595655280507,
#   0.010702925782522216,
#   0.010690285668949454,
#   0.010677675210227586,
#   0.010665094302508598,
#   0.010652542842426555,
#   0.010640020727096369,
#   0.01062752785410993,
#   0.01061506412153394,
#   0.010602629427906783,
#   0.010590223672236217,
#   0.010577846753996444,
#   0.01056549857312529,
#   0.010553179030021967,
#   0.010540888025543708,
#   0.010528625461004021,
#   0.010516391238169562,
#   0.010504185259257207,
#   0.010492007426932445,
#   0.01047985764430589,
#   0.01046773581493138,
#   0.010455641842802902,
#   0.010443575632352625,
#   0.01043153708844795,
#   0.01041952611638949,
#   0.010407542621908166,
#   0.010395586511162905,
#   0.010383657690738565,
#   0.010371756067643158,
#   0.010359881549305467,
#   0.010348034043572762,
#   0.010336213458708457,
#   0.010324419703389922,
#   0.01031265268670575,
#   0.010300912318153756,
#   0.01028919850763871,
#   0.010277511165469948,
#   0.010265850202358952,
#   0.010254215529417621,
#   0.010242607058155197,
#   0.010231024700476897,
#   0.010219468368681367,
#   0.01020793797545828,
#   0.010196433433886482,
#   0.010184954657431713,
#   0.010173501559944382,
#   0.010162074055657618,
#   0.010150672059184941,
#   0.010139295485518231,
#   0.010127944250025896,
#   0.010116618268450311,
#   0.010105317456906324,
#   0.010094041731878438,
#   0.010082791010219793,
#   0.010071565209149102,
#   0.010060364246249367,
#   0.010049188039465855,
#   0.010038036507103472,
#   0.010026909567825421,
#   0.010015807140651279,
#   0.010004729144954498,
#   0.0099936755004609371,
#   0.0099826461272469053,
#   0.0099716409457371261,
#   0.0099606598767027245,
#   0.0099497028412598269,
#   0.0099387697608669598,
#   0.0099278605573240482,
#   0.0099169751527698382,
#   0.0099061134696804588,
#   0.0098952754308674982,
#   0.0098844609594760328,
#   0.0098736699789834896,
#   0.009862902413196685,
#   0.0098521581862511826,
#   0.0098414372226089848,
#   0.0098307394470569191,
#   0.0098200647847047351,
#   0.0098094131609833841,
#   0.0097987845016439395,
#   0.0097881787327547543,
#   0.0097775957807007506,
#   0.0097670355721812211,
#   0.009756498034208293,
#   0.0097459830941051817,
#   0.009735490679504839,
#   0.0097250207183480156,
#   0.0097145731388815493,
#   0.0097041478696570527,
#   0.0096937448395291274,
#   0.0096833639776536841,
#   0.0096730052134866452,
#   0.0096626684767820263,
#   0.0096523536975903941,
#   0.0096420608062576952,
#   0.0096317897334232475,
#   0.009621540410018399,
#   0.009611312767265125,
#   0.0096011067366739977,
#   0.0095909222500434183,
#   0.0095807592394576771,
#   0.009570617637285242,
#   0.0095604973761777168,
#   0.0095503983890682098,
#   0.0095403206091697248,
#   0.0095302639699741277,
#   0.0095202284052501376,
#   0.009510213849042097,
#   0.0095002202356687833,
#   0.0094902474997217087,
#   0.0094802955760639202,
#   0.0094703643998281812,
#   0.0094604539064161251,
#   0.0094505640314966142,
#   0.0094406947110041509,
#   0.0094308458811380481,
#   0.0094210174783603742,
#   0.0094112094393953329,
#   0.009401421701227243,
#   0.0093916542010994905,
#   0.0093819068765136435,
#   0.009372179665227378,
#   0.0093624725052534347,
#   0.0093527853348585425,
#   0.0093431180925620284,
#   0.0093334707171341975,
#   0.0093238431475955418,
#   0.0093142353232153283,
#   0.0093046471835099946,
#   0.0092950786682422792,
#   0.0092855297174196886,
#   0.0092760002712938446,
#   0.0092664902703584445,
#   0.009256999655348444])

# %%
params, grads, costs = optimize(w, b, X, Y, num_iterations= 100, learning_rate = 0.009, print_cost = False)

print ("w = " + str(params["w"]))
print ("b = " + str(params["b"]))
print ("dw = " + str(grads["dw"]))
print ("db = " + str(grads["db"]))
# Out:
# w = [[ 0.19033591]
#  [ 0.12259159]]
# b = 1.92535983008
# dw = [[ 0.67752042]
#  [ 1.41625495]]
# db = 0.219194504541

# %% [markdown]
# **Expected Output**:
#
# <table style="width:40%">
#     <tr>
#        <td> **w** </td>
#        <td>[[ 0.19033591]
#  [ 0.12259159]] </td>
#     </tr>
#
#     <tr>
#        <td> **b** </td>
#        <td> 1.92535983008 </td>
#     </tr>
#     <tr>
#        <td> **dw** </td>
#        <td> [[ 0.67752042]
#  [ 1.41625495]] </td>
#     </tr>
#     <tr>
#        <td> **db** </td>
#        <td> 0.219194504541 </td>
#     </tr>
#
# </table>

# %% [markdown]
# **Exercise:** The previous function will output the learned w and b. We are able to use w and b to predict the labels for a dataset X. Implement the `predict()` function. There are two steps to computing predictions:
#
# 1. Calculate $\hat{Y} = A = \sigma(w^T X + b)$
#
# 2. Convert the entries of a into 0 (if activation <= 0.5) or 1 (if activation > 0.5), stores the predictions in a vector `Y_prediction`. If you wish, you can use an `if`/`else` statement in a `for` loop (though there is also a way to vectorize this).

# %%
# GRADED FUNCTION: predict

def predict(w, b, X):
    '''
    Predict whether the label is 0 or 1 using learned logistic regression parameters (w, b)
    
    Arguments:
    w -- weights, a numpy array of size (num_px * num_px * 3, 1)
    b -- bias, a scalar
    X -- data of size (num_px * num_px * 3, number of examples)
    
    Returns:
    Y_prediction -- a numpy array (vector) containing all predictions (0/1) for the examples in X
    '''
    
    m = X.shape[1]
    Y_prediction = np.zeros((1,m))
    w = w.reshape(X.shape[0], 1)
    
    # Compute vector "A" predicting the probabilities of a cat being present in the picture
    ### START CODE HERE ### (≈ 1 line of code)
    A = sigmoid(np.dot(w.T,X)+b)
    ### END CODE HERE ###
    
    for i in range(A.shape[1]):
        if A[0,i]>0.5:
            Y_prediction[0,i]=1
        elif A[0,i]<=0.5:
            Y_prediction[0,i]=0
                
        
        
        # Convert probabilities A[0,i] to actual predictions p[0,i]
        ### START CODE HERE ### (≈ 4 lines of code)
        pass
        ### END CODE HERE ###
    
    assert(Y_prediction.shape == (1, m))
    
    return Y_prediction

# %%
np.zeros((1,3))[0,0]
# Out:
# 0.0

# %%
w = np.array([[0.1124579],[0.23106775]])
b = -0.3
X = np.array([[1.,-1.1,-3.2],[1.2,2.,0.1]])
A = sigmoid(np.dot(w.T,X)+b)
for i in range(A.shape[1]):
        if A[0,i]>0.5:
            print(1)
        elif A[0,i]<=0.5:
            print(0)
# Out:
# 1
# 1
# 0

# %%
w = np.array([[0.1124579],[0.23106775]])
b = -0.3
X = np.array([[1.,-1.1,-3.2],[1.2,2.,0.1]])
print ("predictions = " + str(predict(w, b, X)))
# Out:
# predictions = [[ 1.  1.  0.]]

# %% [markdown]
# **Expected Output**:
#
# <table style="width:30%">
#     <tr>
#          <td>
#              **predictions**
#          </td>
#           <td>
#             [[ 1.  1.  0.]]
#          </td>
#    </tr>
#
# </table>

# %% [markdown]
# <font color='blue'>
# **What to remember:**
# You've implemented several functions that:
# - Initialize (w,b)
# - Optimize the loss iteratively to learn parameters (w,b):
#     - computing the cost and its gradient
#     - updating the parameters using gradient descent
# - Use the learned (w,b) to predict the labels for a given set of examples

# %% [markdown]
# ## 5 - Merge all functions into a model ##
#
# You will now see how the overall model is structured by putting together all the building blocks (functions implemented in the previous parts) together, in the right order.
#
# **Exercise:** Implement the model function. Use the following notation:
#     - Y_prediction_test for your predictions on the test set
#     - Y_prediction_train for your predictions on the train set
#     - w, costs, grads for the outputs of optimize()

# %%
# GRADED FUNCTION: model

def model(X_train, Y_train, X_test, Y_test, num_iterations = 2000, learning_rate = 0.5, print_cost = False):
    """
    Builds the logistic regression model by calling the function you've implemented previously
    
    Arguments:
    X_train -- training set represented by a numpy array of shape (num_px * num_px * 3, m_train)
    Y_train -- training labels represented by a numpy array (vector) of shape (1, m_train)
    X_test -- test set represented by a numpy array of shape (num_px * num_px * 3, m_test)
    Y_test -- test labels represented by a numpy array (vector) of shape (1, m_test)
    num_iterations -- hyperparameter representing the number of iterations to optimize the parameters
    learning_rate -- hyperparameter representing the learning rate used in the update rule of optimize()
    print_cost -- Set to true to print the cost every 100 iterations
    
    Returns:
    d -- dictionary containing information about the model.
    """
    
    ### START CODE HERE ###
    
    # initialize parameters with zeros (≈ 1 line of code)
    w, b =np.zeros((X_train.shape[0],1)),0

    # Gradient descent (≈ 1 line of code)
    parameters, grads, costs = optimize(w, b, X_train, Y_train, num_iterations, learning_rate, print_cost = False)
    
    # Retrieve parameters w and b from dictionary "parameters"
    w = parameters["w"]
    b = parameters["b"]
    
    # Predict test/train set examples (≈ 2 lines of code)
    Y_prediction_test = predict(w, b, X_test)
    Y_prediction_train = predict(w, b, X_train)

    ### END CODE HERE ###

    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_test - Y_test)) * 100))

    
    d = {"costs": costs,
         "Y_prediction_test": Y_prediction_test, 
         "Y_prediction_train" : Y_prediction_train, 
         "w" : w, 
         "b" : b,
         "learning_rate" : learning_rate,
         "num_iterations": num_iterations}
    
    return d

# %%
train_set_x.shape
# Out:
# (12288, 209)

# %% [markdown]
# Run the following cell to train your model.

# %%
d = model(train_set_x, train_set_y, test_set_x, test_set_y, num_iterations = 2000, learning_rate = 0.005, print_cost = True)
# Out:
# train accuracy: 99.04306220095694 %
# test accuracy: 70.0 %

# %% [markdown]
# **Expected Output**:
#
# <table style="width:40%">
#
#     <tr>
#         <td> **Cost after iteration 0 **  </td>
#         <td> 0.693147 </td>
#     </tr>
#       <tr>
#         <td> <center> $\vdots$ </center> </td>
#         <td> <center> $\vdots$ </center> </td>
#     </tr>
#     <tr>
#         <td> **Train Accuracy**  </td>
#         <td> 99.04306220095694 % </td>
#     </tr>
#
#     <tr>
#         <td>**Test Accuracy** </td>
#         <td> 70.0 % </td>
#     </tr>
# </table>

# %% [markdown]
# **Comment**: Training accuracy is close to 100%. This is a good sanity check: your model is working and has high enough capacity to fit the training data. Test accuracy is 68%. It is actually not bad for this simple model, given the small dataset we used and that logistic regression is a linear classifier. But no worries, you'll build an even better classifier next week!
#
# Also, you see that the model is clearly overfitting the training data. Later in this specialization you will learn how to reduce overfitting, for example by using regularization. Using the code below (and changing the `index` variable) you can look at predictions on pictures of the test set.

# %%
# Example of a picture that was wrongly classified.
index = 1
plt.imshow(test_set_x[:,index].reshape((num_px, num_px, 3)))
print ("y = " + str(test_set_y[0,index]) + ", you predicted that it is a \"" + classes[d["Y_prediction_test"][0,index]].decode("utf-8") +  "\" picture.")
# Out:
# y = 1, you predicted that it is a "cat" picture.

# %% [markdown]
# Let's also plot the cost function and the gradients.

# %%
# Plot learning curve (with costs)
costs = np.squeeze(d['costs'])
plt.plot(costs)
plt.ylabel('cost')
plt.xlabel('iterations (per hundreds)')
plt.title("Learning rate =" + str(d["learning_rate"]))
plt.show()

# %% [markdown]
# **Interpretation**:
# You can see the cost decreasing. It shows that the parameters are being learned. However, you see that you could train the model even more on the training set. Try to increase the number of iterations in the cell above and rerun the cells. You might see that the training set accuracy goes up, but the test set accuracy goes down. This is called overfitting.

# %% [markdown]
# ## 6 - Further analysis (optional/ungraded exercise) ##
#
# Congratulations on building your first image classification model. Let's analyze it further, and examine possible choices for the learning rate $\alpha$.

# %% [markdown]
# #### Choice of learning rate ####
#
# **Reminder**:
# In order for Gradient Descent to work you must choose the learning rate wisely. The learning rate $\alpha$  determines how rapidly we update the parameters. If the learning rate is too large we may "overshoot" the optimal value. Similarly, if it is too small we will need too many iterations to converge to the best values. That's why it is crucial to use a well-tuned learning rate.
#
# Let's compare the learning curve of our model with several choices of learning rates. Run the cell below. This should take about 1 minute. Feel free also to try different values than the three we have initialized the `learning_rates` variable to contain, and see what happens.

# %%
learning_rates = [0.01, 0.001, 0.0001]
models = {}
for i in learning_rates:
    print ("learning rate is: " + str(i))
    models[str(i)] = model(train_set_x, train_set_y, test_set_x, test_set_y, num_iterations = 1500, learning_rate = i, print_cost = False)
    print ('\n' + "-------------------------------------------------------" + '\n')

for i in learning_rates:
    plt.plot(np.squeeze(models[str(i)]["costs"]), label= str(models[str(i)]["learning_rate"]))

plt.ylabel('cost')
plt.xlabel('iterations (hundreds)')

legend = plt.legend(loc='upper center', shadow=True)
frame = legend.get_frame()
frame.set_facecolor('0.90')
plt.show()
# Out:
# learning rate is: 0.01
# train accuracy: 99.52153110047847 %
# test accuracy: 68.0 %
#
# -------------------------------------------------------
#
# learning rate is: 0.001
# train accuracy: 88.99521531100478 %
# test accuracy: 64.0 %
#
# -------------------------------------------------------
#
# learning rate is: 0.0001
# train accuracy: 68.42105263157895 %
# test accuracy: 36.0 %
#
# -------------------------------------------------------

# %% [markdown]
# **Interpretation**:
# - Different learning rates give different costs and thus different predictions results.
# - If the learning rate is too large (0.01), the cost may oscillate up and down. It may even diverge (though in this example, using 0.01 still eventually ends up at a good value for the cost).
# - A lower cost doesn't mean a better model. You have to check if there is possibly overfitting. It happens when the training accuracy is a lot higher than the test accuracy.
# - In deep learning, we usually recommend that you:
#     - Choose the learning rate that better minimizes the cost function.
#     - If your model overfits, use other techniques to reduce overfitting. (We'll talk about this in later videos.)

# %% [markdown]
# ## 7 - Test with your own image (optional/ungraded exercise) ##
#
# Congratulations on finishing this assignment. You can use your own image and see the output of your model. To do that:
#     1. Click on "File" in the upper bar of this notebook, then click "Open" to go on your Coursera Hub.
#     2. Add your image to this Jupyter Notebook's directory, in the "images" folder
#     3. Change your image's name in the following code
#     4. Run the code and check if the algorithm is right (1 = cat, 0 = non-cat)!

# %%
## START CODE HERE ## (PUT YOUR IMAGE NAME) 
my_image = "pisik.jpg"   # change this to the name of your image file 
## END CODE HERE ##

# We preprocess the image to fit your algorithm.
fname = "images/" + my_image
image = np.array(ndimage.imread(fname, flatten=False))
image = image/255.
my_image = scipy.misc.imresize(image, size=(num_px,num_px)).reshape((1, num_px*num_px*3)).T
my_predicted_image = predict(d["w"], d["b"], my_image)

plt.imshow(image)
print("y = " + str(np.squeeze(my_predicted_image)) + ", your algorithm predicts a \"" + classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") +  "\" picture.")
# Out:
# y = 0.0, your algorithm predicts a "non-cat" picture.

# %% [markdown]
# <font color='blue'>
# **What to remember from this assignment:**
# 1. Preprocessing the dataset is important.
# 2. You implemented each function separately: initialize(), propagate(), optimize(). Then you built a model().
# 3. Tuning the learning rate (which is an example of a "hyperparameter") can make a big difference to the algorithm. You will see more examples of this later in this course!

# %% [markdown]
# Finally, if you'd like, we invite you to try different things on this Notebook. Make sure you submit before trying anything. Once you submit, things you can play with include:
#     - Play with the learning rate and the number of iterations
#     - Try different initialization methods and compare the results
#     - Test other preprocessings (center the data, or divide each row by its standard deviation)

# %% [markdown]
# Bibliography:
# - http://www.wildml.com/2015/09/implementing-a-neural-network-from-scratch/
# - https://stats.stackexchange.com/questions/211436/why-do-we-normalize-images-by-subtracting-the-datasets-image-mean-and-not-the-c
